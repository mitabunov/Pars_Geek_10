# %% [markdown]
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     *Наименование вакансии
#     *Предлагаемую зарплату (отдельно мин. и отдельно макс.)
#     *Ссылку на саму вакансию
#     *Сайт откуда собрана вакансия
#
# По своему желанию можно добавить еще работодателя и расположение. Данная структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import json

# %%
headers = {'User-agent' : 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:69.0) Gecko/20100101 Firefox/69.0'}

# %%
# req = requests.get('https://www.superjob.ru/vacancy/search/?keywords=' ,headers=headers)
# req.text
# <div class="_3mfro CuJz5 PlM3e _2JVkc _3LJqf">Стропальщик</div>
# <div class="_3mfro CuJz5 PlM3e _2JVkc _3LJqf">Водитель-дальнобойщик</div>

# %%
main_link = ('https://www.superjob.ru')
# html = requests.get(main_link).text
html = requests.get(main_link+'/vacancy/search/?keywords=', headers=headers).text

parsed_html = bs(html,'lxml')
vac_block = parsed_html.find('div',{'class':'_1Ttd8 _2CsQi'})
vac_list = vac_block.findChildren(recursive=False)
# parsed_html.prettify()

# %%
<div class="_1Ttd8 _2CsQi"><div class="iJCa5 _2gFpt _58AhZ _2p0TS _2nteL"><div class="_1tH7S _1o0Xp _3C76h _3achh _31hDL _2_FIo"><div class="_3zucV undefined"><div class="_1tH7S _1o0Xp _3C76h _3achh _3ofxL _2_FIo"><span class="_3mfro _9fXTd _2JVkc _3e53o">Сортировать:</span><div class="_3zucV undefined _3f-5g"><div class="_3oEK- f-test-select-vacancy _3HfIE _1gwU1"><div class="_2nHo_" role="combobox" aria-expanded="false" aria-haspopup="listbox" aria-labelledby="vacancy-label"><div role="presentation" class="Qz8EF _1NaZX _37tBG _11eNh"><div class="_169nv"><button aria-autocomplete="list" aria-labelledby="vacancy-label" autocomplete="off" value="по дате" id="vacancy-input" type="button" class="f-test-select-button _2fKLm"><div class="f-test-select-selected _1SKZT"><div class="_1JWrU"><div class="_1v2D4 _1-5kc"><div class="_2A7zJ"><span class="_3mfro _2o8cy _2JVkc _2VHxz _3Zhrb">по дате</span></div></div></div></div></button></div><div class="_2ceFh" role="button"><svg viewBox="0 0 24 24" class="_2pknO _3ZJ4b _3MNT6"><use xlink:href="#arrow_drop_down"></use></svg></div></div><div class="cdo9H" style="transition: opacity 150ms ease-in 0s, transform 150ms ease-in 0s; display: none; opacity: 0;"><div class="D0o7w SjSmM _37hg1" style="margin-top: 0px;"><div class="_1v2D4" id="vacancy-item-0"><div class="_2A7zJ"><span class="_3mfro _2o8cy _2JVkc _2VHxz _3Zhrb">по зарплате</span></div></div><div class="_1v2D4 _3By5w" id="vacancy-item-1"><div class="_2A7zJ"><span class="_3mfro _2o8cy _2JVkc _2VHxz _3Zhrb">по дате</span></div></div></div></div></div></div></div></div></div></div></div><hr class="enTIQ _1BgZt _1cZX7 zadqd"><div class="_3zucV _3VcZr"><div class
3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz">от&nbsp;<span>35&nbsp;000</span>&nbsp;<span>₽</span></span></div></div></div></div></div></div><div class="_2g1F-"><div class="_1tH7S _10Aay _3C76h _3achh _3ofxL _2_FIo"><div class="_2kyiZ _2XXYS _2cxK3"><div class="_2g1F-"><span class="_3mfro _9fXTd _2JVkc _2VHxz"><span class="_3mfro _2o8cy _2JVkc _2VHxz">Должностные обязанности:</span> Помогать клиентам в выборе лучших технических новинок. Продавать товары и услуги. Подключать к операторам связи и интернет…</span></div><div class="_2g1F-"><span class="_3mfro _9fXTd _2JVkc _2VHxz"><span class="_3mfro _2o8cy _2JVkc _2VHxz">Требования:</span> Хочешь работать в команде, увлеченной своим делом. Готов учиться и развиваться. У тебя грамотная речь и позитивное отношение…</span></div></div></div></div></div></div><div class="_2g1F-"></div><div class="_2g1F-"><div class="_3Qutk _3fT-Z _2W8_a _2ktKi _1DJDo _29NVe"><div class="_1Ttd8"><div class="_1_bQo _2FJA4 _1iZ5S"><div class="_2g1F-"><button class="_1_Cht f-test-vacancy-response-button f-test-button-Otkliknutsya" tabindex="0" type="button"><span class="qTHqo _3YDqW _1QeOa _24vIk _3evr6" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">Откликнуться</span></span></span></button></div><div class="_2g1F-"><div class="_3wu2D f-test-tooltip- _3TToE _2oiD- NpUCm AVPNH"><div class="_3yxRZ"><div class="f-test-tooltip-interact-area"><button class="_1_Cht f-test-button-Pokazat_kontakty" tabindex="0" type="button"><span class="qTHqo _3YDqW DYJ1Y _2FQ5q" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">Показать контакты</span></span></span></button></div><div class="_3AyK7 _36uTa" style="transition: opacity 100ms linear 0s, transform 100ms linear 0s; display: none; opacity: 0;"><div class="_2ODE0 _3zCNK _3_wME"><div class="_3zucV _2bObt _2tR2A _27aVK _1s0tF"><div class="_36e54 _2ntFx"><div class="_2g1F-"><div class="_1tH7S _1o0Xp GPKTZ _3achh _3ofxL _2_FIo"><span class="_3mfro _1enBN _2JVkc _2VHxz">контакты</span><button class="_1_Cht f-test-button-close" tabindex="0" type="button"><span class="qTHqo _2h9me _2HO6x _1rPPk _1Uw6n" tabindex="-1"><span class="_23m0W"><span class="_3f5Nw"><svg viewBox="0 0 24 24" class="_2pknO _3ZJ4b"><use xlink:href="#close"></use></svg></span></span></span></button></div></div><div class="_2g1F-"><div class="_1_bQo _2FJA4"><div class="_2g1F-"><div class="_3mfro _1hP6a _2JVkc _2VHxz _3LJqf">Войдите для просмотра контактов работодателя</div></div><div class="_2g1F-"><button class="_1_Cht f-test-button-Vojti" tabindex="0" type="button"><span class="qTHqo _2h9me _2HO6x _3yaqt" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">Войти</span></span></span></button></div></div></div></div></div></div></div></div></div></div></div></div><div class="_1Ttd8"><div class="_1_bQo _2FJA4 _1iZ5S"><div class="_2g1F-"><div class="QHavv"><button type="button" class="_1xLyt f-test-clickable-"><span role="button" tabindex="0" class="_1xLyt _1V1Nk f-test-star_border-star _1Mrhs HO2FB f-test-clickable-"><div class="_2q4uC"><svg viewBox="0 0 24 24" class="_2pknO _3ZJ4b _3MNT6"><use xlink:href="#star_border"></use></svg></div><div class="_1Acan"><svg viewBox="0 0 24 24" class="_2pknO _3ZJ4b _3luW8"><use xlink:href="#star"></use></svg></div></span></button><div class="_19fjG">Добавить в избранное</div></div></div><div class="_2g1F-"><div class="_2BDyW"><div class="_9hBiK"><button class="_1_Cht f-test-button-more_vert" tabindex="0" type="button"><span class="qTHqo _1V7H4 _3YDqW DYJ1Y _2FQ5q _31YLM" tabindex="-1"><span class="_23m0W"><span class="_3f5Nw"><svg viewBox="0 0 24 24" class="_2pknO _3ZJ4b"><use xlink:href="#more_vert"></use></svg></span></span></span></button></div></div></div></div></div></div></div><div class="_2g1F-"></div></div></div><div class="_3vuhV"><div class="eWKEC"></div></div></div></div></span><span><hr class="enTIQ x5jRg _1BgZt _1cZX7 _1v4ms zadqd"></span></span></div><hr class="enTIQ _1BgZt _1cZX7 zadqd"><div class="L1p51"><div class="MYD2q"></div><a class="icMQ_ _1_Cht _3ze9n f-test-button-1 f-test-button_active f-test-link-1  undefined" target="_self" href="/vacancy/search/?keywords="><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y _2hh9r" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">1</span></span></span></a><a rel="next" class="icMQ_ _1_Cht _3ze9n f-test-button-2 f-test-link-2" target="_self" href="/vacancy/search/?keywords=&amp;page=2"><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">2</span></span></span></a><a class="icMQ_ _1_Cht _3ze9n f-test-button-3 f-test-link-3" target="_self" href="/vacancy/search/?keywords=&amp;page=3"><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">3</span></span></span></a><a class="icMQ_ _1_Cht _3ze9n f-test-button-4 f-test-link-4" target="_self" href="/vacancy/search/?keywords=&amp;page=4"><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">4</span></span></span></a><a class="icMQ_ _1_Cht _3ze9n f-test-button-5 f-test-link-5" target="_self" href="/vacancy/search/?keywords=&amp;page=5"><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">5</span></span></span></a><span class="_3mfro LZsA8 _1ZlLP _2JVkc _2WqXY">...</span><a class="icMQ_ _1_Cht _3ze9n f-test-button-57 f-test-link-57" target="_self" href="/vacancy/search/?keywords=&amp;page=57"><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">57</span></span></span></a><a rel="next" class="icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-dalshe" target="_self" href="/vacancy/search/?keywords=&amp;page=2"><span class="qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y" tabindex="-1"><span class="_23m0W"><span class="_3IDf-">дальше</span></span></span></a></div></div>

# %%
# [text for text in soup.stripped_strings]

vacancy = []
for vac in vac_list:
    vac_data={}
    main_info = vac.find('div',{'class':'iJCa5 _2gFpt _58AhZ _2p0TS _2nteL'}).findChild()
    vac_name = main_info.get_text()
    vac_link = main_link+main_info['href']
    zp = vac.find('span',{'class':['_3mfro _2Wp8I f-test-text-company-item-salary _1ZlLP _2JVkc _2VHxz', 
                                   '_3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz']})
#     if not rating:
#         rating=0
#     else:
#         rating = rating.getText()
    vac_data['name'] = vac_name
    vac_data['link'] = vac_link
    vac_data['zp'] = zp
    vacancy.append(vac_data)

pprint(vacancy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-5996541fbcf3> in <module>
#       4 for vac in vac_list:
#       5     vac_data={}
# ----> 6     main_info = vac.find('div',{'class':'iJCa5 _2gFpt _58AhZ _2p0TS _2nteL'}).findChild()
#       7     vac_name = main_info.get_text()
#       8     vac_link = main_link+main_info['href']
#
# AttributeError: 'NoneType' object has no attribute 'findChild'

# %%
<div class="vacancy-serp-wrapper HH-SearchVacancyDropClusters-Serp "><div class="bloko-column bloko-column_l-13 bloko-column_m-9 bloko-column_s-8 bloko-column_xs-4"><div data-qa="serp__settings" class="search-filters"><div class="search-filters__item search-filters__item_filter-button"><button class="bloko-button bloko-button_primary HH-SearchVacancyDropClusters-Control">Фильтры 
                (1)
            </button></div><div class="search-filters__sorts"><div class="search-filters__item"><form action=""><script data-name="HH/SubmitOnSelect" data-params=""></script><select name="order_by" data-qa="serp-settings__order-by-menu" class="bloko-select HH-SubmitOnSelect-Value"><option value="publication_time">по дате</option><option value="salary_desc">по убыванию зарплаты</option><option value="salary_asc">по возрастанию зарплаты</option><option value="relevance" selected="">по соответствию</option></select><input type="hidden" name="clusters" value="true"><input type="hidden" name="area" value="1"><input type="hidden" name="text" value="Python"><input type="hidden" name="enable_snippets" value="true"></form></div><div class="search-filters__item"><form action=""><script data-name="HH/SubmitOnSelect" data-params=""></script><select name="search_period" data-qa="serp-settings__search-period-menu" class="bloko-select HH-SubmitOnSelect-Value"><option data-qa="search-period-30 dropdown-menu__item" value="30">за месяц</option><option data-qa="search-period-7 dropdown-menu__item" value="7">за неделю</option><option data-qa="search-period-3 dropdown-menu__item" value="3">за три дня</option><option data-qa="search-period-1 dropdown-menu__item" value="1">за сутки</option></select><input type="hidden" name="clusters" value="true"><input type="hidden" name="area" value="1"><input type="hidden" name="text" value="Python"><input type="hidden" name="enable_snippets" value="true"></form></div></div><div class="search-filters__additional-block"><div class="search-filters__item search-filters__item_map-text"><div class="bloko-button-group bloko-button-group_stretched"><button class="bloko-button bloko-button_pressed bloko-button_stretched">Списком</button><button class="bloko-button bloko-button_stretched HH-SearchVacancyMap-Thumb" data-qa="serp_settings__vacancy-map">На карте</button></div></div><div class="search-filters__item search-filters__item_map-icon"><button class="bloko-button bloko-button_icon-only HH-SearchVacancyMap-Thumb" data-qa="serp_settings__vacancy-map"><span class="bloko-button__icon"><span class="bloko-icon bloko-icon_geolocation bloko-icon_initial-default"></span></span></button></div><!--noindex--><div class="search-filters__item search-filters__item_advanced-text"><a rel="nofollow" class="bloko-button" data-qa="serp_settings__change-query" href="/search/vacancy/advanced?no_default_area&amp;L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python">Изменить запрос</a></div><div class="search-filters__item search-filters__item_list-icon"><button class="bloko-button bloko-button_pressed bloko-button_icon-only"><span class="bloko-button__icon"><span class="bloko-icon bloko-icon_list-more bloko-icon_initial-default"></span></span></button></div><!--/noindex--></div></div><script xmlns:hh="http://schema.reintegration.hh.ru/types" data-name="HH/VacancyToFavorite" data-params="
            {
                &quot;cssClasses&quot;: {
                    &quot;notInFavorites&quot;: &quot;&quot;,
                    &quot;inFavorites&quot;: &quot;vacancy-serp-favorite_selected&quot;
                },
               
        &quot;trl&quot;: {
            &quot;vacancyNotFoundError&quot;: &quot;Вакансия не найдена&quot;,
            &quot;vacancyNotAvailableError&quot;: &quot;Вакансия не доступна&quot;,
            &quot;vacancyNotVisibleError&quot;: &quot;Вакансия невидима&quot;,
            &quot;vacancyArchivedError&quot;: &quot;Вакансия заархивирована&quot;,
            &quot;vacancyAlreadyInFavoriteList&quot;: &quot;Вакансия уже находится в списке избранного&quot;,
            &quot;vacancyNotFoundInFavoriteList&quot;: &quot;Вакансия не найдена в списке избранного&quot;,
            &quot;genericError&quot;: &quot;Извините, сервис временно недоступен. Попробуйте чуть позже.&quot;,
            &quot;vacancyRemove&quot;: &quot;Удалить из избранного&quot;,
            &quot;vacancyAdd&quot;: &quot;В избранное&quot;,
            &quot;limitExceededError&quot;: &quot;У вас слишком много избранных вакансий.&quot;,
            &quot;allowReplacement&quot;: &quot;Удалить самую старую вакансию и добавить эту&quot;,
            &quot;vacancyAddedToFavorite&quot;: &quot;Вакансия добавлена в избранное&quot;
        },
        &quot;isAnonymous&quot;: true
            }
        "></script><div class="bloko-gap bloko-gap_top"><div data-qa="vacancy-serp__results"><script data-name="HH/LinkModifier" data-params="
            {
            
                &quot;additionalParams&quot;: [&quot;position&quot;, &quot;requestId&quot;, &quot;totalVacancies&quot;],
            
            &quot;searchRegExpString&quot;: &quot;/vacancy/([0-9]+)&quot;,
            &quot;replaceString&quot; : &quot;/analytics_source/vacancy/$1&quot;,
            &quot;query&quot;: {
                &quot;source&quot;: [&quot;vacancies&quot;]
        ,&quot;query&quot;: [&quot;Python&quot;]
    
                }
            }
        "></script><div class="vacancy-serp"><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33421599?query=Python" data-position="0" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Стажер Sberseasons Аналитик</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3529?dpt=3529-3529-stat" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Сбербанк для начинающих</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a><!--noindex--><a href="http://hrbrand.ru/" rel="nofollow" data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winner"><span class="bloko-icon bloko-icon_hr-brand bloko-icon_initial-unique"><script data-name="HH/Tooltip/MultiLineHover" data-params="
                    {
                        &quot;text&quot;: [&quot;Победитель Премии HR-бренд&quot;]
                    }
                "></script></span></a><!--noindex--></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Построение словаря метаданных системы. Прототипирование HR аналитики. Анализ взаимодействия клиентов с Банком в рамках продукта «Персональные предложения».</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Владеешь Excel на уровне макросов, SQL или VBA. Понимаешь принципы работ с базами данных. Будет преимуществом знание <span class="highlighted highlighted_short">Python</span>.</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/3529?dpt=3529-3529-stat" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/860036.jpeg" alt="Сбербанк" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33421599&quot;,
                    &quot;employerId&quot;: &quot;3529&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33421599&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">15&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34081444?query=Python" data-position="1" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Team lead Python/Django</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 150&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/4313701" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Мефи24</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Управлять командой разработчиков. Проектировать архитектуру сервиса. Нанимать разработчиков на работу. Проводить ревью задач. Участвовать в разработке.</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт разработки. Знание теории баз данных, опыт работы с MySQL, PostgreSQL. Желателен опыт работы с ASP.NET, JavaScript. Умение разбираться в...</div></div></div><div class="vacancy-serp-item__sidebar">&nbsp;</div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34081444&quot;,
                    &quot;employerId&quot;: &quot;4313701&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34081444&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34048267?query=Python" data-position="2" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Web-аналитик</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/490" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Ренессанс cтрахование, Группа</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a><!--noindex--><a href="http://hrbrand.ru/" rel="nofollow" data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winner"><span class="bloko-icon bloko-icon_hr-brand bloko-icon_initial-unique"><script data-name="HH/Tooltip/MultiLineHover" data-params="
                    {
                        &quot;text&quot;: [&quot;Победитель Премии HR-бренд&quot;]
                    }
                "></script></span></a><!--noindex--></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #915133"></span>Павелецкая</span> и еще 3 <span class="metro-station"><span class="metro-point" style="color: #4FB04F"></span></span><span class="metro-station"><span class="metro-point" style="color: #943E90"></span></span><span class="metro-station"><span class="metro-point" style="color: #BED12C"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработать аналитические dashboards по рекламным кампаниям. Построить модель влияния охватных медиа на конверсии в онлайн каналах. Анализировать аудиторию и сегменты...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт написания JS при решении аналитических задач, знание <span class="highlighted highlighted_short">Python</span>. Опыт работы с BI системами. Опыт работы с большими массивами данных.</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/490" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/2895500.png" alt="Ренессанс cтрахование, Группа" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34048267&quot;,
                    &quot;employerId&quot;: &quot;490&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34048267&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/analytics_source/vacancy/33421592?query=Python&amp;position=3&amp;requestId=1571480330000e36b9f770950085a80f&amp;totalVacancies=2868&amp;source=vacancies" data-position="3" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank" data-clicked="true">Стажер Sberseasons-Data Engineer</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3529?dpt=3529-3529-stat" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Сбербанк для начинающих</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a><!--noindex--><a href="http://hrbrand.ru/" rel="nofollow" data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winner"><span class="bloko-icon bloko-icon_hr-brand bloko-icon_initial-unique"><script data-name="HH/Tooltip/MultiLineHover" data-params="
                    {
                        &quot;text&quot;: [&quot;Победитель Премии HR-бренд&quot;]
                    }
                "></script></span></a><!--noindex--></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Построение пайплайнов для создания новых алгоритмов выявления мошенничества. Разработка витрины для прогнозных моделей на HR-данных.</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">С достаточными знаниями по выбранному направлению для самостоятельной работы над проектами. Готов к масштабным и интересным задачам. Владеешь <span class="highlighted highlighted_short">Python</span>, SQL...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/3529?dpt=3529-3529-stat" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/860036.jpeg" alt="Сбербанк" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33421592&quot;,
                    &quot;employerId&quot;: &quot;3529&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33421592&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">15&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/32077832?query=Python" data-position="4" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Front-end Developer (JavaScript, React)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 150&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/1455?dpt=hh-1455-TECH" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> HeadHunter::Технический департамент</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Алексеевская</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Работу над самым высоконагруженным job-сайтом в России. Продуктовая разработка проработка задачи с первых этапов, декомпозиция, кодинг, отслеживание результатов. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Очень хорошо знает JavaScript и React. Понимает на что нужно обращать внимание при разработке страниц. Командный игрок и хочет обсуждать...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/1455?dpt=hh-1455-TECH" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/2531861.jpeg" alt="HeadHunter" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;32077832&quot;,
                    &quot;employerId&quot;: &quot;1455&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=32077832&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/32144172?query=Python" data-position="5" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Senior Front-end Developer (JavaScript, React)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/1455?dpt=hh-1455-TECH" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> HeadHunter::Технический департамент</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Алексеевская</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Работу над самым высоконагруженным job-сайтом в России. Продуктовая разработка проработка задачи с первых этапов, декомпозиция, кодинг, отслеживание результатов. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Очень хорошо знает JavaScript и React. Понимает на что нужно обращать внимание при разработке страниц. Командный игрок и хочет обсуждать...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/1455?dpt=hh-1455-TECH" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/2531861.jpeg" alt="HeadHunter" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;32144172&quot;,
                    &quot;employerId&quot;: &quot;1455&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=32144172&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div class="serp-special serp-special_large"><div id="67ea7416-15b4-46cb-a125-0206e432f587" class="HHC-Banner-221 banner-place banner-place_221 banner-place-dfp banner-place-dfp_221" data-banner-id="221" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;221&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: 
        {
            &quot;bannerSize&quot;: [970, 90],
            &quot;dfpBannerId&quot;: &quot;HHRU/hh_serp_01&quot;,
            &quot;place&quot;: &quot;221&quot;,
            &quot;type&quot;: &quot;dfp&quot;,
            &quot;bannerId&quot;: &quot;221&quot;,
            &quot;cId&quot;: &quot;67ea7416-15b4-46cb-a125-0206e432f587&quot;,
            &quot;sizeMap&quot;: [],
            &quot;disableAdvRequest&quot;: &quot;&quot;,
            &quot;bannerCommonTargeting&quot;: {&quot;rdp2&quot;: null, &quot;rdp6&quot;: [], &quot;rdp3&quot;: [113, 232, 1], &quot;rdp7&quot;: [], &quot;rdp8&quot;: null, &quot;rdp9&quot;: null, &quot;rdp10&quot;: null, &quot;rdp11&quot;: null, &quot;rdp12&quot;: null, &quot;rdp4&quot;: null, &quot;rdp13&quot;: null, &quot;rdp14&quot;: null, &quot;rdp5&quot;: null, &quot;rdp1&quot;: null, &quot;hhuid&quot;: &quot;cIZU4R05snoUFF2q4dwrFg--&quot;, &quot;locale&quot;: &quot;ru_RU&quot;, &quot;experiments&quot;: [&quot;index_xs_w_rec&quot;, &quot;new_advanced_search_filters&quot;, &quot;vacancy_search_from_employer_page&quot;, &quot;resume_search_by_company_and_industry_experience&quot;, &quot;vacancies_catalog_banners_ab&quot;, &quot;998&quot;, &quot;anonymous_index_xs_with_recommendations&quot;]},
            &quot;bannerAdTargeting&quot;: 
                {
                    &quot;search_type&quot;: &quot;searchVacancy&quot;,
                    &quot;vac_city&quot;: [
        &quot;Москва&quot;
        ],
                    &quot;search_term&quot;: &quot;Python&quot;,
                    &quot;vac_profarea&quot;: [],
                    &quot;vac_specs&quot;: [],
                    &quot;employer_industry&quot;: [],
                    &quot;employer_field&quot;: []
                }
            
        }
    
                }
            "></script></div></div><div class="serp-special serp-special_less-then-large"><div id="fe81a06c-9224-465c-a8fe-88734cd7ded8" class="HHC-Banner-505 banner-place banner-place_505 banner-place-dfp banner-place-dfp_505 banner-place_show" data-banner-id="505" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true" data-google-query-id="CPucgrmMqOUCFY-Fmgod2d0KhQ"><a href="https://hhcdn.ru/click?b=176583&amp;meta=hhuid%3DcIZU4R05snoUFF2q4dwrFg--&amp;domainAreaId=1&amp;place=505&amp;version=0&amp;token=cIZU4R05snoUFF2q4dwrFg--" target="_blank" rel="noopener"><img src="https://hhcdn.ru/nposter/248586.jpg" class="banner-image"></a></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34106577?query=Python" data-position="6" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Data Engineering Team Lead (Python / C++)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">300&nbsp;000-400&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3319598" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> DataFork</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #0072BA"></span>Площадь Революции</span> и еще 1 <span class="metro-station"><span class="metro-point" style="color: #E42313"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Автоматизация процессов сбора, хранения и анализа данных из открытых и закрытых источников (ETL / CMC). Автоматизация процессов обработки, «обогащения» и нормализации...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Умение читать / писать код на <span class="highlighted highlighted_short">python</span> и С++. Опыт разработки в среде linux. Опыт руководства командой 3-5 человек. </div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34106577&quot;,
                    &quot;employerId&quot;: &quot;3319598&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34106577&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33645539?query=Python" data-position="7" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">QA инженер\Тестировщик (автоматизация, Python)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">150&nbsp;000-180&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2060911" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО ЮК-Консалтинг</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Продукт: Автоматическое тестирование модулей продукта. Участие в определении стратегии тестирования. Составление тестовой документации. Владение экспертизой по продукту тестирования. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт в тестировании с автоматизацией на <span class="highlighted highlighted_short">Python</span> от 1 года.</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33645539&quot;,
                    &quot;employerId&quot;: &quot;2060911&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33645539&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33947694?query=Python" data-position="8" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Machine learning engineer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">100&nbsp;000-200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3828175" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Tech5</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility"><resp></resp></div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Хорошее знание аналитической геометрии, линейной алгебры, математической статистики и численных методов. Знание С++/<span class="highlighted highlighted_short">Python</span>, достаточное для решения собственных research-задач. </div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33947694&quot;,
                    &quot;employerId&quot;: &quot;3828175&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33947694&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34005432?query=Python" data-position="9" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python developer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">160&nbsp;000-200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/705624" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> IVIDEON</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #ADACAC"></span>Менделеевская</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Проектировать архитектуру новых сервисов. Автотестить написанное - сейчас код покрыт 800 функциональными тестами. Разрабатывать API приложений и интеграции.</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт разработки микросервисов.</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34005432&quot;,
                    &quot;employerId&quot;: &quot;705624&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34005432&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33895741?query=Python" data-position="10" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python Web Developer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">200&nbsp;000-300&nbsp;000 руб.</div></div></div><div class="vacancy-list-work-schedule HH-Vacancy-Work-Schedule" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="vacancy-serp-item__meta-info"><a href="/employer/1738507" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Soshace</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Safety with regular payments and reliable clients. We use time-tracker to get information on your working hours. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Company that makes remote dev work easy". 3+ years of professional software development experience with JavaScript. 1+ year...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33895741&quot;,
                    &quot;employerId&quot;: &quot;1738507&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33895741&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33833014?query=Python" data-position="11" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Программист Python</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">100&nbsp;000-120&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/873860" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Смарт Текнолоджис,ООО</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка и поддержка приложений в сфере ИИ. Разработка диалоговых систем. Реализация бизнес-логики. Рефакторинг старого кода и проектирование нового. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">...работы <span class="highlighted highlighted_short">python</span> программистом более 3х лет. Отличное знание <span class="highlighted highlighted_short">Python</span>(&gt;3.6), ООП, паттернов проектирования. Наличие реализованных проектов на <span class="highlighted highlighted_short">Python</span>. </div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33833014&quot;,
                    &quot;employerId&quot;: &quot;873860&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33833014&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div class="serp-special serp-special_large"><div id="cedab1e9-0700-440b-9e6b-e0aeec14525b" class="HHC-Banner-175 banner-place banner-place_175 banner-place-dfp banner-place-dfp_175" data-banner-id="175" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;175&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: 
        {
            &quot;bannerSize&quot;: [970, 90],
            &quot;dfpBannerId&quot;: &quot;HHRU/hh_serp_02&quot;,
            &quot;place&quot;: &quot;175&quot;,
            &quot;type&quot;: &quot;dfp&quot;,
            &quot;bannerId&quot;: &quot;175&quot;,
            &quot;cId&quot;: &quot;cedab1e9-0700-440b-9e6b-e0aeec14525b&quot;,
            &quot;sizeMap&quot;: [],
            &quot;disableAdvRequest&quot;: &quot;&quot;,
            &quot;bannerCommonTargeting&quot;: {&quot;rdp2&quot;: null, &quot;rdp6&quot;: [], &quot;rdp3&quot;: [113, 232, 1], &quot;rdp7&quot;: [], &quot;rdp8&quot;: null, &quot;rdp9&quot;: null, &quot;rdp10&quot;: null, &quot;rdp11&quot;: null, &quot;rdp12&quot;: null, &quot;rdp4&quot;: null, &quot;rdp13&quot;: null, &quot;rdp14&quot;: null, &quot;rdp5&quot;: null, &quot;rdp1&quot;: null, &quot;hhuid&quot;: &quot;cIZU4R05snoUFF2q4dwrFg--&quot;, &quot;locale&quot;: &quot;ru_RU&quot;, &quot;experiments&quot;: [&quot;index_xs_w_rec&quot;, &quot;new_advanced_search_filters&quot;, &quot;vacancy_search_from_employer_page&quot;, &quot;resume_search_by_company_and_industry_experience&quot;, &quot;vacancies_catalog_banners_ab&quot;, &quot;998&quot;, &quot;anonymous_index_xs_with_recommendations&quot;]},
            &quot;bannerAdTargeting&quot;: 
                {
                    &quot;search_type&quot;: &quot;searchVacancy&quot;,
                    &quot;vac_city&quot;: [
        &quot;Москва&quot;
        ],
                    &quot;search_term&quot;: &quot;Python&quot;,
                    &quot;vac_profarea&quot;: [],
                    &quot;vac_specs&quot;: [],
                    &quot;employer_industry&quot;: [],
                    &quot;employer_field&quot;: []
                }
            
        }
    
                }
            "></script></div></div><div class="serp-special serp-special_less-then-large"><div id="1a04551d-2360-462a-9760-f3233394fa47" class="HHC-Banner-505 banner-place banner-place_505 banner-place-dfp banner-place-dfp_505 banner-place_show" data-banner-id="505" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true" data-google-query-id="CPPyhLmMqOUCFceVGAodZI0C2A"><a href="https://hhcdn.ru/click?b=176583&amp;meta=hhuid%3DcIZU4R05snoUFF2q4dwrFg--&amp;domainAreaId=1&amp;place=505&amp;version=0&amp;token=cIZU4R05snoUFF2q4dwrFg--" target="_blank" rel="noopener"><img src="https://hhcdn.ru/nposter/248586.jpg" class="banner-image"></a></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33811537?query=Python" data-position="12" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python developer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">150&nbsp;000-200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2234168?dpt=2234168-2234168-msk" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> B2Broker Москва</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #FFCD1C"></span>Деловой центр</span> и еще 2 <span class="metro-station"><span class="metro-point" style="color: #1EBCEF"></span></span><span class="metro-station"><span class="metro-point" style="color: #1EBCEF"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility"><resp></resp></div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Имеет опыт коммерческой разработки на <span class="highlighted highlighted_short">Python</span> 3 от 6 лет. Знает и умеет использовать: итераторы, генераторы, потоки. Отлично владеет знаниями...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/2234168?dpt=2234168-2234168-msk" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/1879130.png" alt="B2Broker" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33811537&quot;,
                    &quot;employerId&quot;: &quot;2234168&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33811537&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33953502?query=Python" data-position="13" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Junior Python developer, ML-engineer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">45&nbsp;000-80&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/4108548" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Целус Менеджмент</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Внедрять готовые решения: создавать приложения, диалоговые системы, реализовывать api. Создавать тесты и документацию. Анализировать и структурировать данные и метаданные. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">pet projects). Умение писать красивый и поддерживаемый код. Уверенное использование <span class="highlighted highlighted_short">Python</span>, базовое знание C++. Знание основ GIT. Знание или интерес...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33953502&quot;,
                    &quot;employerId&quot;: &quot;4108548&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33953502&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33840192?query=Python" data-position="14" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python Data Scientist</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 150&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/5552" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Web Interactive World</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #0072BA"></span>Площадь Революции</span> и еще 3 <span class="metro-station"><span class="metro-point" style="color: #943E90"></span></span><span class="metro-station"><span class="metro-point" style="color: #4FB04F"></span></span><span class="metro-station"><span class="metro-point" style="color: #E42313"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Работа с большими объемами структурированных и неструктурированных данных. Подготовка данных, выявление закономерностей на признаках, feature engineering. Построение, оценка и внедрение...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Хорошая математическая подготовка, владение основами статистики, умение объяснить и доказать полученный результат. Отличное владение <span class="highlighted highlighted_short">Python</span> и ML-стеком (statsmodels, sklearn...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33840192&quot;,
                    &quot;employerId&quot;: &quot;5552&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33840192&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33923247?query=Python" data-position="15" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python Developer</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2129243" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ЗАО ОКБ</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Третьяковская</span> и еще 2 <span class="metro-station"><span class="metro-point" style="color: #4FB04F"></span></span><span class="metro-station"><span class="metro-point" style="color: #FFCD1C"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка и проектирование frontend’a для продуктов компании. Совместная работа в кросс-функциональной команде. Разработка архитектуры приложения с нуля. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Уверенные знания <span class="highlighted highlighted_short">Python</span>. Проектирование API для взаимодействия сервисов. Владение ОПП; использовать принцип SOLID. Умение писать unit-тесты. Опыт использования шаблонов...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33923247&quot;,
                    &quot;employerId&quot;: &quot;2129243&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33923247&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34161888?query=Python" data-position="16" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python разработчик</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">110&nbsp;000-110&nbsp;000 руб.</div></div></div><div class="vacancy-list-work-schedule HH-Vacancy-Work-Schedule" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="vacancy-serp-item__meta-info"><a href="/employer/3086591" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Диджитал медикэл оперейшнс</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Реализация сервисов на языке <span class="highlighted highlighted_short">Python</span>. Разработка бэкэнда для сервисов машинного обучения и интеллектуальных систем. Реализация алгоритмов для графов, онтологий, байесовских...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы в области создания программного обеспечения в качестве разработчика 1-3 года и выше. Понимание принципов ООП и шаблонов...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34161888&quot;,
                    &quot;employerId&quot;: &quot;3086591&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34161888&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33842117?query=Python" data-position="17" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Методист-эксперт Python</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">130&nbsp;000-180&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2657797" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Алгоритмика</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">...оценки результатов учебной деятельности обучающихся отделения. Внесение предложений по совершенствованию образовательного процесса. Требования: Экспертиза в <span class="highlighted highlighted_short">Python</span> (преподавание + обучение преподавателей).</div><div data-qa="vacancy-serp__vacancy_snippet_requirement"><req></req></div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33842117&quot;,
                    &quot;employerId&quot;: &quot;2657797&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33842117&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33917948?query=Python" data-position="18" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Разработчик Python / Django</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">70&nbsp;000-80&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/1334502" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> IT Gene</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Свиблово</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Поддержка и разработка порталов‚ обеспечивающих взаимодействие заказчика с распределенной сетью контрагентов (написаны на Django). Поддержка механизмов обмена данных между порталами...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы в аналогичной должности от двух лет. Опыт разработки на <span class="highlighted highlighted_short">Python</span> 2.7 и 3.5‚ Django 1.8...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33917948&quot;,
                    &quot;employerId&quot;: &quot;1334502&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33917948&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33875623?query=Python" data-position="19" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Разработчик Python</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">до 120&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3197321" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Кузница Кадров</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Проектирование и реализация законченных функциональных модулей системы. Ввод системы в промышленную эксплуатацию. Работа на стеке: Oracle/Hadoop/Teradata, <span class="highlighted highlighted_short">Python</span>/Spark...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">...<span class="highlighted highlighted_short">Python</span> или Java от 1 года. Уверенные знания SQL. Знание реляционных баз данных (RDB). Желание развиваться в разработке на <span class="highlighted highlighted_short">Python</span>.</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33875623&quot;,
                    &quot;employerId&quot;: &quot;3197321&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33875623&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item"><span class="bloko-link bloko-link_dimmed" data-qa="vacancy-serp__vacancy_contacts"><span class="vacancy-serp-item__control vacancy-serp-item__control_gt-xs">Показать контакты</span><span class="vacancy-serp-item__control vacancy-serp-item__control_xs-only">Контакты</span><script data-name="HH/VacancyContactsLoader/VacancyContactsLoader" data-params="
                    {
                        &quot;id&quot;: 33875623,
                        &quot;employerId&quot;: 3197321,
                        &quot;trl&quot;: {
                            &quot;error&quot;: &quot;Произошла ошибка. Попробуйте перезагрузить страницу.&quot;
                        }
                    }
                "></script><script data-name="HH/SendAnalytics" data-params="
                    {
                        &quot;onEvent&quot;: &quot;click&quot;,
                        &quot;category&quot;: &quot;anonymous&quot;,
                        &quot;action&quot;: &quot;vacancy-view-contacts&quot;,
                        &quot;label&quot;: &quot;open&quot;
                    }
                "></script></span></span><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div class="vacancy-serp__sticky-filters-button"><button class="bloko-button                                         bloko-button_primary                                         bloko-button_stretched                                         HH-SearchVacancyDropClusters-Control">Фильтр и сортировки</button></div></div></div></div><div class="serp-special serp-special_under-results"><div id="banner_654" class="HHC-Banner-654 banner-place banner-place_654 clickme-banner_fluid banner-place_show" data-banner-id="654" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;654&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script><iframe style="width: 240px; height: 120px;" src="https://hhcdn.ru/nposter/147113.html" scrolling="no" class=" banner-place-iframe-654" frameborder="no"></iframe></div><div id="banner_655" class="HHC-Banner-655 banner-place banner-place_655 clickme-banner_fluid banner-place_show" data-banner-id="655" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;655&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script><iframe style="width: 240px; height: 120px;" src="https://hhcdn.ru/nposter/147113.html" scrolling="no" class=" banner-place-iframe-655" frameborder="no"></iframe></div></div><div class="serp-special serp-special_under-results serp-special_under-results-xs-only"><div id="banner_661" class="HHC-Banner-661 banner-place banner-place_661 clickme-banner_fluid" data-banner-id="661" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;661&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script></div><div id="banner_662" class="HHC-Banner-662 banner-place banner-place_662 clickme-banner_fluid" data-banner-id="662" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;662&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script></div><div id="banner_663" class="HHC-Banner-663 banner-place banner-place_663 clickme-banner_fluid" data-banner-id="663" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;663&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script></div></div><div class="search-suggestion"><div class="search-suggestion__header search-suggestion__header_level-3">Попробуйте другие варианты поискового запроса</div><div class="bloko-column bloko-column_m-4 bloko-column_l-4 bloko-column_container"><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+python&amp;from=SIMILAR_QUERY">программист python</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=python+django&amp;from=SIMILAR_QUERY">python django</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=python+%D1%83%D0%B4%D0%B0%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE&amp;from=SIMILAR_QUERY">python удаленно</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=php+python&amp;from=SIMILAR_QUERY">php python</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=python+developer&amp;from=SIMILAR_QUERY">python developer</a></div></div><div class="bloko-column bloko-column_m-4 bloko-column_l-4 bloko-column_container"><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=django&amp;from=SIMILAR_QUERY">django</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=perl&amp;from=SIMILAR_QUERY">perl</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=ruby&amp;from=SIMILAR_QUERY">ruby</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=erlang&amp;from=SIMILAR_QUERY">erlang</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=linux&amp;from=SIMILAR_QUERY">linux</a></div></div></div><div class="saved-search-subscription-wrapper saved-search-subscription-wrapper_fixed saved-search-subscription-wrapper_collapsed"><script data-name="HH/Search/SavedSearchSubscription" data-params="
            {
                &quot;cssClasses&quot;: {
                    &quot;sticky&quot;: &quot;saved-search-subscription-wrapper_fixed&quot;,
                    &quot;mobile&quot;: &quot;saved-search-subscription-wrapper_mobile&quot;,
                    &quot;collapsed&quot;: &quot;saved-search-subscription-wrapper_collapsed&quot;
                },
                &quot;visible&quot;: true,
                &quot;trl&quot;: {
                    &quot;error&quot;: &quot;Произошла ошибка. Попробуйте позже.&quot;
                },
                &quot;url&quot;: &quot;/vacancysavedsearch/save?area=1&amp;enable_snippets=true&amp;text=Python&quot;,
                &quot;collapseUrl&quot;: &quot;/savesearch/collapse?subject=vacancy&quot;
            }
        "></script><script data-name="HH/Form" data-params="
            {
                &quot;conditions&quot;: {
                    &quot;email&quot;: {
                        &quot;string&quot;: {
                            &quot;required&quot;: true,
                            &quot;regexp&quot;: &quot;^[^\\s]+@[^\\s]+\\.[^\\s]+$&quot;
                        }
                    }
                },
                &quot;messages&quot;: {
                    &quot;email&quot;: {
                        &quot;empty&quot;: &quot;Указан некорректный e-mail&quot;,
                        &quot;regexpFail&quot;: &quot;Указан некорректный e-mail&quot;
                    }
                }
            }
        "></script><script data-name="HH/Bloko/StateChanger" data-params="
            {
                &quot;initial&quot;: {
                    &quot;action&quot;: &quot;swap&quot;,
                    &quot;target&quot;: &quot;form&quot;
                }
            }
        "></script><div class="saved-search-subscription-wrapper__content"><div class="saved-search-subscription-plane"></div><form class="HH-Form-Form HH-Search-SavedSearchSubscription-Form"><script data-name="HH/Form/BaseForm" data-params=""></script><div data-change-group="form"><div class="bloko-form-row"><div class="saved-search-subscription-text">Подпишитесь на&nbsp;результаты поиска по&nbsp;этому запросу, чтобы не&nbsp;пропустить интересные предложения</div></div><div class="saved-search-subscription-content-wrapper"><span class="HH-Form-Element-TooltipElement saved-search-subscription-email"><script data-name="HH/Search/SavedSearchSubscriptionError" data-params="
                        {
                            &quot;fieldName&quot;: &quot;email&quot;,
                            &quot;uid&quot;: &quot;0000-0000-0000-0000&quot;
                        }
                    "></script><span class="bloko-form-item"><input type="text" class="HH-Form-ChangableError-Value HH-Search-SavedSearchSubscription-Email bloko-input" placeholder="Адрес электронной почты" data-qa="autosearch-subscribe__email"></span></span><span class="bloko-form-spacer"><button class="bloko-button                        bloko-button_secondary                        HH-Form-SubmitButton                        HH-Search-SavedSearchSubscription-Loading" data-qa="autosearch-subscribe__submit"><span class="bloko-button__content">Подписаться</span><span class="bloko-button__loading"><span class="bloko-icon bloko-icon_loading bloko-icon_initial-primary"></span></span></button></span></div></div><div class="g-hidden" data-change-group="success" data-qa="vacancy-serp__search-saved">На указанный адрес отправлено письмо с подтверждением. <br>Чтобы начать следить за вакансиями, <br>перейдите по ссылке в письме</div><div class="g-hidden" data-change-group="auth-required"><div class="bloko-form-row">Указанный email уже зарегистрирован.
                <br>Авторизуйтесь на сайте как соискатель
и сохраните запрос еще раз.</div><a href="/account/login?backUrl=%2Fsearch%2Fvacancy%3Farea%3D1%26st%3DsearchVacancy%26text%3DPython%26from%3Dsuggest_post" class="bloko-button bloko-button_primary">Авторизоваться</a></div></form><span class="HH-Search-SavedSearchSubscription-Toggle saved-search-subscription-wrapper__closer ">×</span></div><div class="saved-search-subscription-wrapper__teaser"><div class="saved-search-subscription-plane                             saved-search-subscription-plane_collapsed                             HH-Search-SavedSearchSubscription-Toggle"></div></div></div><div class="bloko-gap bloko-gap_top"><!--noindex--><div data-qa="pager-block"><script data-name="HH/Pager" data-params="
                    {
                        &quot;isAjax&quot;: false,
                        &quot;currentPage&quot;: 0,
                        &quot;pagesCount&quot;: 6
                    }
                "></script><span class="bloko-button-group"><span class="bloko-button bloko-button_pressed" data-qa="pager-page">1</span><span class=""><a class="bloko-button HH-Pager-Control" data-page="1" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=1">2</a></span><span class=""><a class="bloko-button HH-Pager-Control" data-page="2" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=2">3</a></span><span class="pager-item-not-in-short-range"><a class="bloko-button HH-Pager-Control" data-page="3" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=3">4</a></span><span class="pager-item-not-in-short-range"><a class="bloko-button HH-Pager-Control" data-page="4" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=4">5</a></span></span><span class="bloko-form-spacer"></span><span class="pager-item-not-in-short-range">
            …
            <span class="bloko-form-spacer"></span><a class="bloko-button HH-Pager-Control" data-page="99" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=99">100</a><span class="bloko-form-spacer"></span></span><a class="bloko-button HH-Pager-Controls-Next HH-Pager-Control" data-qa="pager-next" data-page="1" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=1">дальше</a><span class="bloko-form-spacer"></span></div><!--/noindex--></div></div></div>

# %%
https://hh.ru/search/vacancy?area=1&st=searchVacancy&text=Python&from=suggest_post

# %%
<div class="sticky-container"><script data-name="HH/Sticky/ParentAreaResizer" data-params="
                {
                    &quot;screenParams&quot;: {
                        &quot;XS&quot;: false,
                        &quot;S&quot;: false
                    },
                    &quot;saveWidth&quot;: true
                }
            "></script><div class="HH-StickyParentAreaResizer-Content"><div class="search-preference-wrapper HH-SearchVacancyDropClusters-Clusters "><div class="bloko-column bloko-column_l-3 bloko-column_m-3 bloko-column_s-4 bloko-column_xs-4"><div style="visibility: hidden; height: 906.1px; width: 210px; margin: 0px; display: none;"></div><div class="search-preference HH-StickyParentAreaResizer-Area HH-Sticky-Block" style="width: 210px; position: static; margin-left: 0px; top: 0px;"><div class="search-preference__item"><div xmlns:hh="http://schema.reintegration.hh.ru/types" class="clusters"><div class="clusters__links" data-qa="serp__clusters"><div class="clusters-group_sorting"><div class="bloko-form-group"><div class="bloko-form-item"><div class="clusters-group-title">Сортировка</div></div><div class="bloko-form-item"><form action=""><script data-name="HH/SubmitOnSelect" data-params=""></script><select name="order_by" data-qa="serp-settings__order-by-menu" class="bloko-select HH-SubmitOnSelect-Value"><option value="publication_time">по дате</option><option value="salary_desc">по убыванию зарплаты</option><option value="salary_asc">по возрастанию зарплаты</option><option value="relevance" selected="">по соответствию</option></select><input type="hidden" name="clusters" value="true"><input type="hidden" name="area" value="1"><input type="hidden" name="text" value="Python"><input type="hidden" name="enable_snippets" value="true"></form></div><div class="bloko-form-item"><form action=""><script data-name="HH/SubmitOnSelect" data-params=""></script><select name="search_period" data-qa="serp-settings__search-period-menu" class="bloko-select HH-SubmitOnSelect-Value"><option data-qa="search-period-30 dropdown-menu__item" value="30">за месяц</option><option data-qa="search-period-7 dropdown-menu__item" value="7">за неделю</option><option data-qa="search-period-3 dropdown-menu__item" value="3">за три дня</option><option data-qa="search-period-1 dropdown-menu__item" value="1">за сутки</option></select><input type="hidden" name="clusters" value="true"><input type="hidden" name="area" value="1"><input type="hidden" name="text" value="Python"><input type="hidden" name="enable_snippets" value="true"></form></div></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_expand"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;area&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="area" data-qa="serp__cluster-group-title">Регион<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value clusters-value_selected" href="?clusters=true&amp;enable_snippets=true&amp;text=Python&amp;showClusters=true" data-qa="serp__criterion"><span class="clusters-value__name">Москва</span><span class="clusters-value__close"><span class="clusters-value__close-icon"><span class="bloko-icon bloko-icon_cancel"></span></span></span></a><!--/noindex--></li></ul></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_expand"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;neighbours&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="neighbours" data-qa="serp__cluster-group-title">Соседние города<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2088&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Зеленоград</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">29</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2077&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Химки</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">9</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2085&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Долгопрудный</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">7</span></a><!--/noindex--></li><li class="clusters-list__item                    clusters-list__item_more" data-toggle="" data-qa="serp__cluster-item"><span class="clusters-items-more" data-qa="serp__cluster-item-show-more">Еще 8</span></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2041&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Мытищи</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">4</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2061&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Подольск (Московская область)</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">2</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2065&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Раменское</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">2</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2023&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Дмитров</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2090&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Королев</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2092&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Лобня</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2064&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Жуковский</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?clusters=true&amp;text=Python&amp;enable_snippets=true&amp;area=2098&amp;from=NEIGHBOURS&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title">Электросталь</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li></ul></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_expand"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;metro&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="metro" data-qa="serp__cluster-group-title">Метро<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=2&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #4FB04F"></span>Замоскворецкая</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">563</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=5&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #915133"></span>Кольцевая</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">430</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=9&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #ADACAC"></span>Серпуховско-Тимирязевская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">384</span></a><!--/noindex--></li><li class="clusters-list__item                    clusters-list__item_more" data-toggle="" data-qa="serp__cluster-item"><span class="clusters-items-more" data-qa="serp__cluster-item-show-more">Еще 11</span></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=7&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #943E90"></span>Таганско-Краснопресненская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">262</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=6&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #F07E24"></span>Калужско-Рижская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">220</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=1&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #E42313"></span>Сокольническая</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">218</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=3&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #0072BA"></span>Арбатско-Покровская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">204</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=4&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #1EBCEF"></span>Филевская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">192</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=10&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #BED12C"></span>Люблинско-Дмитровская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">173</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=8&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #FFCD1C"></span>Калининская</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">168</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=95&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #F9BCD1"></span>Московское центральное кольцо</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">51</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;metro=97&amp;from=cluster_metro&amp;showClusters=true"><span class="clusters-value__name clusters-value__name_truncate" data-qa="serp__cluster-item-title"><span class="metro-point" style="color: #88CDCF"></span>Большая кольцевая линия</span><span class="clusters-value__count" data-qa="serp__cluster-item-number
amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Тяжелое машиностроение</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">12</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=45&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Добывающая отрасль</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">12</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=15&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Автомобильный бизнес</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">11</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=24&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Металлургия, металлообработка</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">11</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=27&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Продукты питания</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">10</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=46&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Энергетика</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">6</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=52&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Искусство, культура</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">6</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=37&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Общественная деятельность, партии, благотворительность, НКО</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">5</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=50&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Гостиницы, рестораны, общепит, кейтеринг</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">4</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=19&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Лесная промышленность, деревообработка</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">3</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=389&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Управление многопрофильными активами</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">2</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=29&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Сельское хозяйство</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li><li class="clusters-list__item clusters-list__item_expandable" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;industry=34&amp;from=cluster_industry&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Химическое производство, удобрения</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1</span></a><!--/noindex--></li></ul></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_collapse"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;experience&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="experience" data-qa="serp__cluster-group-title">Опыт работы<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;experience=between1And3&amp;from=cluster_experience&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">От&nbsp;1&nbsp;года до&nbsp;3&nbsp;лет</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1364</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;experience=between3And6&amp;from=cluster_experience&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">От&nbsp;3&nbsp;до&nbsp;6&nbsp;лет</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">1016</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;experience=noExperience&amp;from=cluster_experience&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Нет опыта</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">393</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;experience=moreThan6&amp;from=cluster_experience&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Более 6&nbsp;лет</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">95</span></a><!--/noindex--></li></ul></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_collapse"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;employment&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="employment" data-qa="serp__cluster-group-title">Тип занятости<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;employment=full&amp;from=cluster_employment&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Полная занятость</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">2772</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;employment=probation&amp;from=cluster_employment&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Стажировка</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">61</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;employment=part&amp;from=cluster_employment&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Частичная занятость</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">23</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;employment=project&amp;from=cluster_employment&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Проектная работа</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">12</span></a><!--/noindex--></li></ul></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_collapse"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;schedule&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="schedule" data-qa="serp__cluster-group-title">График работы<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;schedule=fullDay&amp;from=cluster_schedule&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Полный день</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">2525</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;schedule=flexible&amp;from=cluster_schedule&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Гибкий график</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">224</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;schedule=remote&amp;from=cluster_schedule&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Удаленная работа</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">106</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;schedule=shift&amp;from=cluster_schedule&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Сменный график</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">13</span></a><!--/noindex--></li></ul></div></div><div data-qa="serp__cluster-group" class="clusters-group clusters-group_collapse"><script data-name="HH/AnimateToggle" data-params="
                {
                    &quot;direction&quot;: &quot;height&quot;,
                    &quot;animationClass&quot;: &quot;clusters-group__animation&quot;
                }
            "></script><script data-name="HH/Bloko/Toggle" data-params="
                {
                    &quot;collapseClass&quot;: &quot;clusters-group_collapse&quot;,
                    &quot;expandClass&quot;: &quot;clusters-group_expand&quot;,
                    &quot;name&quot;: &quot;label&quot;
                }
            "></script><div class="clusters-group-title                         clusters-group-title_selectable" data-toggle="label" data-qa="serp__cluster-group-title">Исключение<span class="clusters-group-title__expander"></span></div><div class="clusters-group__items"><ul class="clusters-list" data-qa="serp__cluster-group-item"><script data-name="HH/Bloko/Toggle" data-params="
                        {
                            &quot;expandClass&quot;: &quot;clusters-list_expand&quot;
                        }
                    "></script><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;label=accept_handicapped&amp;from=cluster_label&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Только доступные для людей с&nbsp;инвалидностью</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">35</span></a><!--/noindex--></li><li class="clusters-list__item" data-qa="serp__cluster-item"><!--noindex--><a rel="nofollow" class="clusters-value" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;label=not_from_agency&amp;from=cluster_label&amp;showClusters=true"><span class="clusters-value__name" data-qa="serp__cluster-item-title">Без вакансий агентств</span><span class="clusters-value__count" data-qa="serp__cluster-item-number">2735</span></a><!--/noindex--></li></ul></div></div></div><div class="clusters__close"><button class="bloko-button                                bloko-button_primary                                bloko-button_stretched                                HH-SearchVacancyDropClusters-Control">Показать 2&nbsp;868&nbsp;вакансий</button></div></div></div></div></div></div><div class="vacancy-serp-wrapper HH-SearchVacancyDropClusters-Serp "><div class="bloko-column bloko-column_l-13 bloko-column_m-9 bloko-column_s-8 bloko-column_xs-4"><div data-qa="serp__settings" class="search-filters"><div class="search-filters__item search-filters__item_filter-button"><button class="bloko-button bloko-button_primary HH-SearchVacancyDropClusters-Control">Фильтры 
                (1)
            </button></div><div class="search-filters__sorts"><div class="search-filters__item"><form action=""><script data-name="HH/SubmitOnSelect" data-params=""></script><select name="order_by" data-qa="serp-settings__order-by-menu" class="bloko-select HH-SubmitOnSelect-Value"><option value="publication_time">по дате</option><option value="salary_desc">по убыванию зарплаты</option><option value="salary_asc">по возрастанию зарплаты</option><option value="relevance" selected="">по соответствию</option></select><input type="hidden" name="clusters" value="true"><input type="hidden" name="area" value="1"><input type="hidden" name="text" value="Python"><input type="hidden" name="enable_snippets" value="true"></form></div><div class="search-filters__item"><form action=""><script data-name="HH/SubmitOnSelect" data-params=""></script><select name="search_period" data-qa="serp-settings__search-period-menu" class="bloko-select HH-SubmitOnSelect-Value"><option data-qa="search-period-30 dropdown-menu__item" value="30">за месяц</option><option data-qa="search-period-7 dropdown-menu__item" value="7">за неделю</option><option data-qa="search-period-3 dropdown-menu__item" value="3">за три дня</option><option data-qa="search-period-1 dropdown-menu__item" value="1">за сутки</option></select><input type="hidden" name="clusters" value="true"><input type="hidden" name="area" value="1"><input type="hidden" name="text" value="Python"><input type="hidden" name="enable_snippets" value="true"></form></div></div><div class="search-filters__additional-block"><div class="search-filters__item search-filters__item_map-text"><div class="bloko-button-group bloko-button-group_stretched"><button class="bloko-button bloko-button_pressed bloko-button_stretched">Списком</button><button class="bloko-button bloko-button_stretched HH-SearchVacancyMap-Thumb" data-qa="serp_settings__vacancy-map">На карте</button></div></div><div class="search-filters__item search-filters__item_map-icon"><button class="bloko-button bloko-button_icon-only HH-SearchVacancyMap-Thumb" data-qa="serp_settings__vacancy-map"><span class="bloko-button__icon"><span class="bloko-icon bloko-icon_geolocation bloko-icon_initial-default"></span></span></button></div><!--noindex--><div class="search-filters__item search-filters__item_advanced-text"><a rel="nofollow" class="bloko-button" data-qa="serp_settings__change-query" href="/search/vacancy/advanced?no_default_area&amp;L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python">Изменить запрос</a></div><div class="search-filters__item search-filters__item_list-icon"><button class="bloko-button bloko-button_pressed bloko-button_icon-only"><span class="bloko-button__icon"><span class="bloko-icon bloko-icon_list-more bloko-icon_initial-default"></span></span></button></div><!--/noindex--></div></div><script xmlns:hh="http://schema.reintegration.hh.ru/types" data-name="HH/VacancyToFavorite" data-params="
            {
                &quot;cssClasses&quot;: {
                    &quot;notInFavorites&quot;: &quot;&quot;,
                    &quot;inFavorites&quot;: &quot;vacancy-serp-favorite_selected&quot;
                },
               
        &quot;trl&quot;: {
            &quot;vacancyNotFoundError&quot;: &quot;Вакансия не найдена&quot;,
            &quot;vacancyNotAvailableError&quot;: &quot;Вакансия не доступна&quot;,
            &quot;vacancyNotVisibleError&quot;: &quot;Вакансия невидима&quot;,
            &quot;vacancyArchivedError&quot;: &quot;Вакансия заархивирована&quot;,
            &quot;vacancyAlreadyInFavoriteList&quot;: &quot;Вакансия уже находится в списке избранного&quot;,
            &quot;vacancyNotFoundInFavoriteList&quot;: &quot;Вакансия не найдена в списке избранного&quot;,
            &quot;genericError&quot;: &quot;Извините, сервис временно недоступен. Попробуйте чуть позже.&quot;,
            &quot;vacancyRemove&quot;: &quot;Удалить из избранного&quot;,
            &quot;vacancyAdd&quot;: &quot;В избранное&quot;,
            &quot;limitExceededError&quot;: &quot;У вас слишком много избранных вакансий.&quot;,
            &quot;allowReplacement&quot;: &quot;Удалить самую старую вакансию и добавить эту&quot;,
            &quot;vacancyAddedToFavorite&quot;: &quot;Вакансия добавлена в избранное&quot;
        },
        &quot;isAnonymous&quot;: true
            }
        "></script><div class="bloko-gap bloko-gap_top"><div data-qa="vacancy-serp__results"><script data-name="HH/LinkModifier" data-params="
            {
            
                &quot;additionalParams&quot;: [&quot;position&quot;, &quot;requestId&quot;, &quot;totalVacancies&quot;],
            
            &quot;searchRegExpString&quot;: &quot;/vacancy/([0-9]+)&quot;,
            &quot;replaceString&quot; : &quot;/analytics_source/vacancy/$1&quot;,
            &quot;query&quot;: {
                &quot;source&quot;: [&quot;vacancies&quot;]
        ,&quot;query&quot;: [&quot;Python&quot;]
    
                }
            }
        "></script><div class="vacancy-serp"><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33421599?query=Python" data-position="0" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Стажер Sberseasons Аналитик</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3529?dpt=3529-3529-stat" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Сбербанк для начинающих</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a><!--noindex--><a href="http://hrbrand.ru/" rel="nofollow" data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winner"><span class="bloko-icon bloko-icon_hr-brand bloko-icon_initial-unique"><script data-name="HH/Tooltip/MultiLineHover" data-params="
                    {
                        &quot;text&quot;: [&quot;Победитель Премии HR-бренд&quot;]
                    }
                "></script></span></a><!--noindex--></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Построение словаря метаданных системы. Прототипирование HR аналитики. Анализ взаимодействия клиентов с Банком в рамках продукта «Персональные предложения».</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Владеешь Excel на уровне макросов, SQL или VBA. Понимаешь принципы работ с базами данных. Будет преимуществом знание <span class="highlighted highlighted_short">Python</span>.</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/3529?dpt=3529-3529-stat" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/860036.jpeg" alt="Сбербанк" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33421599&quot;,
                    &quot;employerId&quot;: &quot;3529&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33421599&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">15&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34081444?query=Python" data-position="1" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Team lead Python/Django</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 150&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/4313701" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Мефи24</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Управлять командой разработчиков. Проектировать архитектуру сервиса. Нанимать разработчиков на работу. Проводить ревью задач. Участвовать в разработке.</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт разработки. Знание теории баз данных, опыт работы с MySQL, PostgreSQL. Желателен опыт работы с ASP.NET, JavaScript. Умение разбираться в...</div></div></div><div class="vacancy-serp-item__sidebar">&nbsp;</div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34081444&quot;,
                    &quot;employerId&quot;: &quot;4313701&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34081444&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34048267?query=Python" data-position="2" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Web-аналитик</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/490" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Ренессанс cтрахование, Группа</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a><!--noindex--><a href="http://hrbrand.ru/" rel="nofollow" data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winner"><span class="bloko-icon bloko-icon_hr-brand bloko-icon_initial-unique"><script data-name="HH/Tooltip/MultiLineHover" data-params="
                    {
                        &quot;text&quot;: [&quot;Победитель Премии HR-бренд&quot;]
                    }
                "></script></span></a><!--noindex--></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #915133"></span>Павелецкая</span> и еще 3 <span class="metro-station"><span class="metro-point" style="color: #4FB04F"></span></span><span class="metro-station"><span class="metro-point" style="color: #943E90"></span></span><span class="metro-station"><span class="metro-point" style="color: #BED12C"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработать аналитические dashboards по рекламным кампаниям. Построить модель влияния охватных медиа на конверсии в онлайн каналах. Анализировать аудиторию и сегменты...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт написания JS при решении аналитических задач, знание <span class="highlighted highlighted_short">Python</span>. Опыт работы с BI системами. Опыт работы с большими массивами данных.</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/490" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/2895500.png" alt="Ренессанс cтрахование, Группа" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34048267&quot;,
                    &quot;employerId&quot;: &quot;490&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34048267&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/analytics_source/vacancy/33421592?query=Python&amp;position=3&amp;requestId=1571480330000e36b9f770950085a80f&amp;totalVacancies=2868&amp;source=vacancies" data-position="3" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank" data-clicked="true">Стажер Sberseasons-Data Engineer</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3529?dpt=3529-3529-stat" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Сбербанк для начинающих</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a><!--noindex--><a href="http://hrbrand.ru/" rel="nofollow" data-qa="vacancy-serp__vacancy_hrbrand vacancy-serp__vacancy_hrbrand_winner"><span class="bloko-icon bloko-icon_hr-brand bloko-icon_initial-unique"><script data-name="HH/Tooltip/MultiLineHover" data-params="
                    {
                        &quot;text&quot;: [&quot;Победитель Премии HR-бренд&quot;]
                    }
                "></script></span></a><!--noindex--></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Построение пайплайнов для создания новых алгоритмов выявления мошенничества. Разработка витрины для прогнозных моделей на HR-данных.</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">С достаточными знаниями по выбранному направлению для самостоятельной работы над проектами. Готов к масштабным и интересным задачам. Владеешь <span class="highlighted highlighted_short">Python</span>, SQL...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/3529?dpt=3529-3529-stat" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/860036.jpeg" alt="Сбербанк" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33421592&quot;,
                    &quot;employerId&quot;: &quot;3529&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33421592&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">15&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/32077832?query=Python" data-position="4" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Front-end Developer (JavaScript, React)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 150&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/1455?dpt=hh-1455-TECH" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> HeadHunter::Технический департамент</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Алексеевская</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Работу над самым высоконагруженным job-сайтом в России. Продуктовая разработка проработка задачи с первых этапов, декомпозиция, кодинг, отслеживание результатов. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Очень хорошо знает JavaScript и React. Понимает на что нужно обращать внимание при разработке страниц. Командный игрок и хочет обсуждать...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/1455?dpt=hh-1455-TECH" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/2531861.jpeg" alt="HeadHunter" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;32077832&quot;,
                    &quot;employerId&quot;: &quot;1455&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=32077832&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy vacancy-serp__vacancy_premium" class="vacancy-serp-item  vacancy-serp-item_premium"><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/32144172?query=Python" data-position="5" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Senior Front-end Developer (JavaScript, React)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/1455?dpt=hh-1455-TECH" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> HeadHunter::Технический департамент</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Алексеевская</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Работу над самым высоконагруженным job-сайтом в России. Продуктовая разработка проработка задачи с первых этапов, декомпозиция, кодинг, отслеживание результатов. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Очень хорошо знает JavaScript и React. Понимает на что нужно обращать внимание при разработке страниц. Командный игрок и хочет обсуждать...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/1455?dpt=hh-1455-TECH" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/2531861.jpeg" alt="HeadHunter" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;32144172&quot;,
                    &quot;employerId&quot;: &quot;1455&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=32144172&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">14&nbsp;октября</span></span></div></div><div class="serp-special serp-special_large"><div id="67ea7416-15b4-46cb-a125-0206e432f587" class="HHC-Banner-221 banner-place banner-place_221 banner-place-dfp banner-place-dfp_221" data-banner-id="221" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;221&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: 
        {
            &quot;bannerSize&quot;: [970, 90],
            &quot;dfpBannerId&quot;: &quot;HHRU/hh_serp_01&quot;,
            &quot;place&quot;: &quot;221&quot;,
            &quot;type&quot;: &quot;dfp&quot;,
            &quot;bannerId&quot;: &quot;221&quot;,
            &quot;cId&quot;: &quot;67ea7416-15b4-46cb-a125-0206e432f587&quot;,
            &quot;sizeMap&quot;: [],
            &quot;disableAdvRequest&quot;: &quot;&quot;,
            &quot;bannerCommonTargeting&quot;: {&quot;rdp2&quot;: null, &quot;rdp6&quot;: [], &quot;rdp3&quot;: [113, 232, 1], &quot;rdp7&quot;: [], &quot;rdp8&quot;: null, &quot;rdp9&quot;: null, &quot;rdp10&quot;: null, &quot;rdp11&quot;: null, &quot;rdp12&quot;: null, &quot;rdp4&quot;: null, &quot;rdp13&quot;: null, &quot;rdp14&quot;: null, &quot;rdp5&quot;: null, &quot;rdp1&quot;: null, &quot;hhuid&quot;: &quot;cIZU4R05snoUFF2q4dwrFg--&quot;, &quot;locale&quot;: &quot;ru_RU&quot;, &quot;experiments&quot;: [&quot;index_xs_w_rec&quot;, &quot;new_advanced_search_filters&quot;, &quot;vacancy_search_from_employer_page&quot;, &quot;resume_search_by_company_and_industry_experience&quot;, &quot;vacancies_catalog_banners_ab&quot;, &quot;998&quot;, &quot;anonymous_index_xs_with_recommendations&quot;]},
            &quot;bannerAdTargeting&quot;: 
                {
                    &quot;search_type&quot;: &quot;searchVacancy&quot;,
                    &quot;vac_city&quot;: [
        &quot;Москва&quot;
        ],
                    &quot;search_term&quot;: &quot;Python&quot;,
                    &quot;vac_profarea&quot;: [],
                    &quot;vac_specs&quot;: [],
                    &quot;employer_industry&quot;: [],
                    &quot;employer_field&quot;: []
                }
            
        }
    
                }
            "></script></div></div><div class="serp-special serp-special_less-then-large"><div id="fe81a06c-9224-465c-a8fe-88734cd7ded8" class="HHC-Banner-505 banner-place banner-place_505 banner-place-dfp banner-place-dfp_505 banner-place_show" data-banner-id="505" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true" data-google-query-id="CPucgrmMqOUCFY-Fmgod2d0KhQ"><a href="https://hhcdn.ru/click?b=176583&amp;meta=hhuid%3DcIZU4R05snoUFF2q4dwrFg--&amp;domainAreaId=1&amp;place=505&amp;version=0&amp;token=cIZU4R05snoUFF2q4dwrFg--" target="_blank" rel="noopener"><img src="https://hhcdn.ru/nposter/248586.jpg" class="banner-image"></a></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34106577?query=Python" data-position="6" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Data Engineering Team Lead (Python / C++)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">300&nbsp;000-400&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3319598" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> DataFork</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #0072BA"></span>Площадь Революции</span> и еще 1 <span class="metro-station"><span class="metro-point" style="color: #E42313"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Автоматизация процессов сбора, хранения и анализа данных из открытых и закрытых источников (ETL / CMC). Автоматизация процессов обработки, «обогащения» и нормализации...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Умение читать / писать код на <span class="highlighted highlighted_short">python</span> и С++. Опыт разработки в среде linux. Опыт руководства командой 3-5 человек. </div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34106577&quot;,
                    &quot;employerId&quot;: &quot;3319598&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34106577&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33645539?query=Python" data-position="7" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">QA инженер\Тестировщик (автоматизация, Python)</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">150&nbsp;000-180&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2060911" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО ЮК-Консалтинг</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Продукт: Автоматическое тестирование модулей продукта. Участие в определении стратегии тестирования. Составление тестовой документации. Владение экспертизой по продукту тестирования. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт в тестировании с автоматизацией на <span class="highlighted highlighted_short">Python</span> от 1 года.</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33645539&quot;,
                    &quot;employerId&quot;: &quot;2060911&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33645539&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33947694?query=Python" data-position="8" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Machine learning engineer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">100&nbsp;000-200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3828175" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Tech5</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility"><resp></resp></div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Хорошее знание аналитической геометрии, линейной алгебры, математической статистики и численных методов. Знание С++/<span class="highlighted highlighted_short">Python</span>, достаточное для решения собственных research-задач. </div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33947694&quot;,
                    &quot;employerId&quot;: &quot;3828175&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33947694&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34005432?query=Python" data-position="9" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python developer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">160&nbsp;000-200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/705624" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> IVIDEON</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #ADACAC"></span>Менделеевская</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Проектировать архитектуру новых сервисов. Автотестить написанное - сейчас код покрыт 800 функциональными тестами. Разрабатывать API приложений и интеграции.</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт разработки микросервисов.</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34005432&quot;,
                    &quot;employerId&quot;: &quot;705624&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34005432&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33895741?query=Python" data-position="10" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python Web Developer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">200&nbsp;000-300&nbsp;000 руб.</div></div></div><div class="vacancy-list-work-schedule HH-Vacancy-Work-Schedule" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="vacancy-serp-item__meta-info"><a href="/employer/1738507" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Soshace</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Safety with regular payments and reliable clients. We use time-tracker to get information on your working hours. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Company that makes remote dev work easy". 3+ years of professional software development experience with JavaScript. 1+ year...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33895741&quot;,
                    &quot;employerId&quot;: &quot;1738507&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33895741&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33833014?query=Python" data-position="11" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Программист Python</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">100&nbsp;000-120&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/873860" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Смарт Текнолоджис,ООО</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка и поддержка приложений в сфере ИИ. Разработка диалоговых систем. Реализация бизнес-логики. Рефакторинг старого кода и проектирование нового. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">...работы <span class="highlighted highlighted_short">python</span> программистом более 3х лет. Отличное знание <span class="highlighted highlighted_short">Python</span>(&gt;3.6), ООП, паттернов проектирования. Наличие реализованных проектов на <span class="highlighted highlighted_short">Python</span>. </div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33833014&quot;,
                    &quot;employerId&quot;: &quot;873860&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33833014&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div class="serp-special serp-special_large"><div id="cedab1e9-0700-440b-9e6b-e0aeec14525b" class="HHC-Banner-175 banner-place banner-place_175 banner-place-dfp banner-place-dfp_175" data-banner-id="175" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;175&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: 
        {
            &quot;bannerSize&quot;: [970, 90],
            &quot;dfpBannerId&quot;: &quot;HHRU/hh_serp_02&quot;,
            &quot;place&quot;: &quot;175&quot;,
            &quot;type&quot;: &quot;dfp&quot;,
            &quot;bannerId&quot;: &quot;175&quot;,
            &quot;cId&quot;: &quot;cedab1e9-0700-440b-9e6b-e0aeec14525b&quot;,
            &quot;sizeMap&quot;: [],
            &quot;disableAdvRequest&quot;: &quot;&quot;,
            &quot;bannerCommonTargeting&quot;: {&quot;rdp2&quot;: null, &quot;rdp6&quot;: [], &quot;rdp3&quot;: [113, 232, 1], &quot;rdp7&quot;: [], &quot;rdp8&quot;: null, &quot;rdp9&quot;: null, &quot;rdp10&quot;: null, &quot;rdp11&quot;: null, &quot;rdp12&quot;: null, &quot;rdp4&quot;: null, &quot;rdp13&quot;: null, &quot;rdp14&quot;: null, &quot;rdp5&quot;: null, &quot;rdp1&quot;: null, &quot;hhuid&quot;: &quot;cIZU4R05snoUFF2q4dwrFg--&quot;, &quot;locale&quot;: &quot;ru_RU&quot;, &quot;experiments&quot;: [&quot;index_xs_w_rec&quot;, &quot;new_advanced_search_filters&quot;, &quot;vacancy_search_from_employer_page&quot;, &quot;resume_search_by_company_and_industry_experience&quot;, &quot;vacancies_catalog_banners_ab&quot;, &quot;998&quot;, &quot;anonymous_index_xs_with_recommendations&quot;]},
            &quot;bannerAdTargeting&quot;: 
                {
                    &quot;search_type&quot;: &quot;searchVacancy&quot;,
                    &quot;vac_city&quot;: [
        &quot;Москва&quot;
        ],
                    &quot;search_term&quot;: &quot;Python&quot;,
                    &quot;vac_profarea&quot;: [],
                    &quot;vac_specs&quot;: [],
                    &quot;employer_industry&quot;: [],
                    &quot;employer_field&quot;: []
                }
            
        }
    
                }
            "></script></div></div><div class="serp-special serp-special_less-then-large"><div id="1a04551d-2360-462a-9760-f3233394fa47" class="HHC-Banner-505 banner-place banner-place_505 banner-place-dfp banner-place-dfp_505 banner-place_show" data-banner-id="505" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true" data-google-query-id="CPPyhLmMqOUCFceVGAodZI0C2A"><a href="https://hhcdn.ru/click?b=176583&amp;meta=hhuid%3DcIZU4R05snoUFF2q4dwrFg--&amp;domainAreaId=1&amp;place=505&amp;version=0&amp;token=cIZU4R05snoUFF2q4dwrFg--" target="_blank" rel="noopener"><img src="https://hhcdn.ru/nposter/248586.jpg" class="banner-image"></a></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33811537?query=Python" data-position="12" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python developer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">150&nbsp;000-200&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2234168?dpt=2234168-2234168-msk" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> B2Broker Москва</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #FFCD1C"></span>Деловой центр</span> и еще 2 <span class="metro-station"><span class="metro-point" style="color: #1EBCEF"></span></span><span class="metro-station"><span class="metro-point" style="color: #1EBCEF"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility"><resp></resp></div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Имеет опыт коммерческой разработки на <span class="highlighted highlighted_short">Python</span> 3 от 6 лет. Знает и умеет использовать: итераторы, генераторы, потоки. Отлично владеет знаниями...</div></div></div><div class="vacancy-serp-item__sidebar"><a href="/employer/2234168?dpt=2234168-2234168-msk" data-qa="vacancy-serp__vacancy-employer-logo"><img src="https://hhcdn.ru/employer-logo/1879130.png" alt="B2Broker" class="vacancy-serp-item__logo"></a></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33811537&quot;,
                    &quot;employerId&quot;: &quot;2234168&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33811537&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33953502?query=Python" data-position="13" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Junior Python developer, ML-engineer</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">45&nbsp;000-80&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/4108548" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Целус Менеджмент</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Внедрять готовые решения: создавать приложения, диалоговые системы, реализовывать api. Создавать тесты и документацию. Анализировать и структурировать данные и метаданные. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">pet projects). Умение писать красивый и поддерживаемый код. Уверенное использование <span class="highlighted highlighted_short">Python</span>, базовое знание C++. Знание основ GIT. Знание или интерес...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33953502&quot;,
                    &quot;employerId&quot;: &quot;4108548&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33953502&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33840192?query=Python" data-position="14" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python Data Scientist</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">от 150&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/5552" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Web Interactive World</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #0072BA"></span>Площадь Революции</span> и еще 3 <span class="metro-station"><span class="metro-point" style="color: #943E90"></span></span><span class="metro-station"><span class="metro-point" style="color: #4FB04F"></span></span><span class="metro-station"><span class="metro-point" style="color: #E42313"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Работа с большими объемами структурированных и неструктурированных данных. Подготовка данных, выявление закономерностей на признаках, feature engineering. Построение, оценка и внедрение...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Хорошая математическая подготовка, владение основами статистики, умение объяснить и доказать полученный результат. Отличное владение <span class="highlighted highlighted_short">Python</span> и ML-стеком (statsmodels, sklearn...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33840192&quot;,
                    &quot;employerId&quot;: &quot;5552&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33840192&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33923247?query=Python" data-position="15" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python Developer</a></span></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2129243" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ЗАО ОКБ</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Третьяковская</span> и еще 2 <span class="metro-station"><span class="metro-point" style="color: #4FB04F"></span></span><span class="metro-station"><span class="metro-point" style="color: #FFCD1C"></span></span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Разработка и проектирование frontend’a для продуктов компании. Совместная работа в кросс-функциональной команде. Разработка архитектуры приложения с нуля. </div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Уверенные знания <span class="highlighted highlighted_short">Python</span>. Проектирование API для взаимодействия сервисов. Владение ОПП; использовать принцип SOLID. Умение писать unit-тесты. Опыт использования шаблонов...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33923247&quot;,
                    &quot;employerId&quot;: &quot;2129243&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33923247&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/34161888?query=Python" data-position="16" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Python разработчик</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">110&nbsp;000-110&nbsp;000 руб.</div></div></div><div class="vacancy-list-work-schedule HH-Vacancy-Work-Schedule" data-qa="vacancy-serp__vacancy-work-schedule">Можно работать из дома</div><div class="vacancy-serp-item__meta-info"><a href="/employer/3086591" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Диджитал медикэл оперейшнс</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Реализация сервисов на языке <span class="highlighted highlighted_short">Python</span>. Разработка бэкэнда для сервисов машинного обучения и интеллектуальных систем. Реализация алгоритмов для графов, онтологий, байесовских...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы в области создания программного обеспечения в качестве разработчика 1-3 года и выше. Понимание принципов ООП и шаблонов...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;34161888&quot;,
                    &quot;employerId&quot;: &quot;3086591&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=34161888&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33842117?query=Python" data-position="17" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Методист-эксперт Python</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">130&nbsp;000-180&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/2657797" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> Алгоритмика</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">...оценки результатов учебной деятельности обучающихся отделения. Внесение предложений по совершенствованию образовательного процесса. Требования: Экспертиза в <span class="highlighted highlighted_short">Python</span> (преподавание + обучение преподавателей).</div><div data-qa="vacancy-serp__vacancy_snippet_requirement"><req></req></div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33842117&quot;,
                    &quot;employerId&quot;: &quot;2657797&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33842117&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33917948?query=Python" data-position="18" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Разработчик Python / Django</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">70&nbsp;000-80&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/1334502" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer"> IT Gene</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва, <span class="metro-station"><span class="metro-point" style="color: #F07E24"></span>Свиблово</span></span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Поддержка и разработка порталов‚ обеспечивающих взаимодействие заказчика с распределенной сетью контрагентов (написаны на Django). Поддержка механизмов обмена данных между порталами...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">Опыт работы в аналогичной должности от двух лет. Опыт разработки на <span class="highlighted highlighted_short">Python</span> 2.7 и 3.5‚ Django 1.8...</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33917948&quot;,
                    &quot;employerId&quot;: &quot;1334502&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33917948&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">19&nbsp;октября</span></span></div></div><div data-qa="vacancy-serp__vacancy" class="vacancy-serp-item "><script data-name="HH/VacancyResponseTrigger" data-params=""></script><div class="vacancy-serp-item__row vacancy-serp-item__row_header"><div class="vacancy-serp-item__info"><div class="resume-search-item__name"><span class="g-user-content"><a class="bloko-link HH-LinkModifier" data-qa="vacancy-serp__vacancy-title" href="https://hh.ru/vacancy/33875623?query=Python" data-position="19" data-requestid="1571480330000e36b9f770950085a80f" data-totalvacancies="2868" target="_blank">Разработчик Python</a></span></div></div><div class="vacancy-serp-item__sidebar"><div class="vacancy-serp-item__compensation" data-qa="vacancy-serp__vacancy-compensation">до 120&nbsp;000 руб.</div></div></div><div class="vacancy-serp-item__meta-info"><a href="/employer/3197321" class="bloko-link bloko-link_secondary HH-AnonymousIndexAnalytics-Recommended-Company" data-qa="vacancy-serp__vacancy-employer">ООО Кузница Кадров</a>&nbsp;<a class="bloko-link" target="_blank" href="https://feedback.hh.ru/article/details/id/5951"><span class="bloko-icon bloko-icon_done bloko-icon_initial-action"><script data-name="HH/Tooltip/Hover" data-params="
                    {
                        &quot;placement&quot;: &quot;right&quot;,
                        &quot;html&quot;: &quot;Компания прошла проверку на сайте&quot;,
                        &quot;layer&quot;: &quot;overlay&quot;
                    }
                "></script></span></a></div><div class="vacancy-serp-item__meta-info"><span class="vacancy-serp-item__meta-info" data-qa="vacancy-serp__vacancy-address">Москва</span></div><div class="vacancy-serp-item__row"><div class="vacancy-serp-item__info"><div class="g-user-content"><div data-qa="vacancy-serp__vacancy_snippet_responsibility">Проектирование и реализация законченных функциональных модулей системы. Ввод системы в промышленную эксплуатацию. Работа на стеке: Oracle/Hadoop/Teradata, <span class="highlighted highlighted_short">Python</span>/Spark...</div><div data-qa="vacancy-serp__vacancy_snippet_requirement">...<span class="highlighted highlighted_short">Python</span> или Java от 1 года. Уверенные знания SQL. Знание реляционных баз данных (RDB). Желание развиваться в разработке на <span class="highlighted highlighted_short">Python</span>.</div></div></div><div class="vacancy-serp-item__sidebar"></div></div><div class="vacancy-serp-item__row vacancy-serp-item__row_controls"><div class="HH-VacancyResponseTrigger-Button"><script data-name="HH/VacancyResponsePopup/VacancyResponsePopup" data-params="
                {
                    &quot;isAutoOpen&quot;: false,
                    &quot;stayOnPage&quot;: true,
                    &quot;vacancyId&quot;: &quot;33875623&quot;,
                    &quot;employerId&quot;: &quot;3197321&quot;,
                    &quot;isWithoutTest&quot;: true,
                    &quot;ignoreResponseCheck&quot;: true,
                    &quot;trl&quot;: {
                        &quot;responseTitle&quot;: &quot;Резюме доставлено&quot;,
                        &quot;responseStats&quot;: &quot;Этот работодатель просматривает {0}% поступивших резюме&quot;,
                        &quot;responseNoStats&quot;: &quot;Узнать о статусе резюме можно на странице откликов&quot;,
                        &quot;viewResponse&quot;: &quot;Посмотреть&quot;,
                        &quot;viewResponses&quot;: &quot;Смотреть отклики&quot;
                    }
                }
            "></script><span class="vacancy-serp-item__controls-item"><a href="/applicant/vacancy_response?vacancyId=33875623&amp;hhtmSource=vacancy_search_result" class="bloko-link bloko-link_dimmed HH-VacancyResponsePopup-Link" data-qa="vacancy-serp__vacancy_response">Откликнуться</a></span></div><div class="vacancy-serp-item__controls-item HH-VacancyResponseTrigger-Container g-hidden"><a href="/negotiations/gotopic?vacancy_id=" target="_blank" class="search-resume-item-label" data-qa="vacancy-serp__vacancy_responded">Вы откликнулись</a></div><span class="vacancy-serp-item__controls-item"><span class="bloko-link bloko-link_dimmed" data-qa="vacancy-serp__vacancy_contacts"><span class="vacancy-serp-item__control vacancy-serp-item__control_gt-xs">Показать контакты</span><span class="vacancy-serp-item__control vacancy-serp-item__control_xs-only">Контакты</span><script data-name="HH/VacancyContactsLoader/VacancyContactsLoader" data-params="
                    {
                        &quot;id&quot;: 33875623,
                        &quot;employerId&quot;: 3197321,
                        &quot;trl&quot;: {
                            &quot;error&quot;: &quot;Произошла ошибка. Попробуйте перезагрузить страницу.&quot;
                        }
                    }
                "></script><script data-name="HH/SendAnalytics" data-params="
                    {
                        &quot;onEvent&quot;: &quot;click&quot;,
                        &quot;category&quot;: &quot;anonymous&quot;,
                        &quot;action&quot;: &quot;vacancy-view-contacts&quot;,
                        &quot;label&quot;: &quot;open&quot;
                    }
                "></script></span></span><span class="vacancy-serp-item__controls-item vacancy-serp-item__controls-item_last" data-qa="vacancy-serp__vacancy-date"><span class="vacancy-serp-item__publication-date">18&nbsp;октября</span></span></div></div><div class="vacancy-serp__sticky-filters-button"><button class="bloko-button                                         bloko-button_primary                                         bloko-button_stretched                                         HH-SearchVacancyDropClusters-Control">Фильтр и сортировки</button></div></div></div></div><div class="serp-special serp-special_under-results"><div id="banner_654" class="HHC-Banner-654 banner-place banner-place_654 clickme-banner_fluid banner-place_show" data-banner-id="654" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;654&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script><iframe style="width: 240px; height: 120px;" src="https://hhcdn.ru/nposter/147113.html" scrolling="no" class=" banner-place-iframe-654" frameborder="no"></iframe></div><div id="banner_655" class="HHC-Banner-655 banner-place banner-place_655 clickme-banner_fluid banner-place_show" data-banner-id="655" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="false" data-requested="true" data-loaded="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;655&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script><iframe style="width: 240px; height: 120px;" src="https://hhcdn.ru/nposter/147113.html" scrolling="no" class=" banner-place-iframe-655" frameborder="no"></iframe></div></div><div class="serp-special serp-special_under-results serp-special_under-results-xs-only"><div id="banner_661" class="HHC-Banner-661 banner-place banner-place_661 clickme-banner_fluid" data-banner-id="661" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;661&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script></div><div id="banner_662" class="HHC-Banner-662 banner-place banner-place_662 clickme-banner_fluid" data-banner-id="662" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;662&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script></div><div id="banner_663" class="HHC-Banner-663 banner-place banner-place_663 clickme-banner_fluid" data-banner-id="663" data-empty-class="banner-place_hide" data-loaded-class="banner-place_show" data-banner-additional-class="" data-listeners-setted="true"><script data-name="HH/LoadBannerOnVisible" data-params="
                {
                    &quot;id&quot;: &quot;663&quot;,
                    &quot;templateName&quot;: &quot;&quot;,
                    &quot;dfpParams&quot;: {}
                }
            "></script></div></div><div class="search-suggestion"><div class="search-suggestion__header search-suggestion__header_level-3">Попробуйте другие варианты поискового запроса</div><div class="bloko-column bloko-column_m-4 bloko-column_l-4 bloko-column_container"><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=%D0%BF%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%81%D1%82+python&amp;from=SIMILAR_QUERY">программист python</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=python+django&amp;from=SIMILAR_QUERY">python django</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=python+%D1%83%D0%B4%D0%B0%D0%BB%D0%B5%D0%BD%D0%BD%D0%BE&amp;from=SIMILAR_QUERY">python удаленно</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=php+python&amp;from=SIMILAR_QUERY">php python</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=python+developer&amp;from=SIMILAR_QUERY">python developer</a></div></div><div class="bloko-column bloko-column_m-4 bloko-column_l-4 bloko-column_container"><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=django&amp;from=SIMILAR_QUERY">django</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=perl&amp;from=SIMILAR_QUERY">perl</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=ruby&amp;from=SIMILAR_QUERY">ruby</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=erlang&amp;from=SIMILAR_QUERY">erlang</a></div><div class="bloko-form-item"><a class="bloko-link" href="?area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=linux&amp;from=SIMILAR_QUERY">linux</a></div></div></div><div class="saved-search-subscription-wrapper saved-search-subscription-wrapper_fixed saved-search-subscription-wrapper_collapsed"><script data-name="HH/Search/SavedSearchSubscription" data-params="
            {
                &quot;cssClasses&quot;: {
                    &quot;sticky&quot;: &quot;saved-search-subscription-wrapper_fixed&quot;,
                    &quot;mobile&quot;: &quot;saved-search-subscription-wrapper_mobile&quot;,
                    &quot;collapsed&quot;: &quot;saved-search-subscription-wrapper_collapsed&quot;
                },
                &quot;visible&quot;: true,
                &quot;trl&quot;: {
                    &quot;error&quot;: &quot;Произошла ошибка. Попробуйте позже.&quot;
                },
                &quot;url&quot;: &quot;/vacancysavedsearch/save?area=1&amp;enable_snippets=true&amp;text=Python&quot;,
                &quot;collapseUrl&quot;: &quot;/savesearch/collapse?subject=vacancy&quot;
            }
        "></script><script data-name="HH/Form" data-params="
            {
                &quot;conditions&quot;: {
                    &quot;email&quot;: {
                        &quot;string&quot;: {
                            &quot;required&quot;: true,
                            &quot;regexp&quot;: &quot;^[^\\s]+@[^\\s]+\\.[^\\s]+$&quot;
                        }
                    }
                },
                &quot;messages&quot;: {
                    &quot;email&quot;: {
                        &quot;empty&quot;: &quot;Указан некорректный e-mail&quot;,
                        &quot;regexpFail&quot;: &quot;Указан некорректный e-mail&quot;
                    }
                }
            }
        "></script><script data-name="HH/Bloko/StateChanger" data-params="
            {
                &quot;initial&quot;: {
                    &quot;action&quot;: &quot;swap&quot;,
                    &quot;target&quot;: &quot;form&quot;
                }
            }
        "></script><div class="saved-search-subscription-wrapper__content"><div class="saved-search-subscription-plane"></div><form class="HH-Form-Form HH-Search-SavedSearchSubscription-Form"><script data-name="HH/Form/BaseForm" data-params=""></script><div data-change-group="form"><div class="bloko-form-row"><div class="saved-search-subscription-text">Подпишитесь на&nbsp;результаты поиска по&nbsp;этому запросу, чтобы не&nbsp;пропустить интересные предложения</div></div><div class="saved-search-subscription-content-wrapper"><span class="HH-Form-Element-TooltipElement saved-search-subscription-email"><script data-name="HH/Search/SavedSearchSubscriptionError" data-params="
                        {
                            &quot;fieldName&quot;: &quot;email&quot;,
                            &quot;uid&quot;: &quot;0000-0000-0000-0000&quot;
                        }
                    "></script><span class="bloko-form-item"><input type="text" class="HH-Form-ChangableError-Value HH-Search-SavedSearchSubscription-Email bloko-input" placeholder="Адрес электронной почты" data-qa="autosearch-subscribe__email"></span></span><span class="bloko-form-spacer"><button class="bloko-button                        bloko-button_secondary                        HH-Form-SubmitButton                        HH-Search-SavedSearchSubscription-Loading" data-qa="autosearch-subscribe__submit"><span class="bloko-button__content">Подписаться</span><span class="bloko-button__loading"><span class="bloko-icon bloko-icon_loading bloko-icon_initial-primary"></span></span></button></span></div></div><div class="g-hidden" data-change-group="success" data-qa="vacancy-serp__search-saved">На указанный адрес отправлено письмо с подтверждением. <br>Чтобы начать следить за вакансиями, <br>перейдите по ссылке в письме</div><div class="g-hidden" data-change-group="auth-required"><div class="bloko-form-row">Указанный email уже зарегистрирован.
                <br>Авторизуйтесь на сайте как соискатель
и сохраните запрос еще раз.</div><a href="/account/login?backUrl=%2Fsearch%2Fvacancy%3Farea%3D1%26st%3DsearchVacancy%26text%3DPython%26from%3Dsuggest_post" class="bloko-button bloko-button_primary">Авторизоваться</a></div></form><span class="HH-Search-SavedSearchSubscription-Toggle saved-search-subscription-wrapper__closer ">×</span></div><div class="saved-search-subscription-wrapper__teaser"><div class="saved-search-subscription-plane                             saved-search-subscription-plane_collapsed                             HH-Search-SavedSearchSubscription-Toggle"></div></div></div><div class="bloko-gap bloko-gap_top"><!--noindex--><div data-qa="pager-block"><script data-name="HH/Pager" data-params="
                    {
                        &quot;isAjax&quot;: false,
                        &quot;currentPage&quot;: 0,
                        &quot;pagesCount&quot;: 6
                    }
                "></script><span class="bloko-button-group"><span class="bloko-button bloko-button_pressed" data-qa="pager-page">1</span><span class=""><a class="bloko-button HH-Pager-Control" data-page="1" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=1">2</a></span><span class=""><a class="bloko-button HH-Pager-Control" data-page="2" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=2">3</a></span><span class="pager-item-not-in-short-range"><a class="bloko-button HH-Pager-Control" data-page="3" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=3">4</a></span><span class="pager-item-not-in-short-range"><a class="bloko-button HH-Pager-Control" data-page="4" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=4">5</a></span></span><span class="bloko-form-spacer"></span><span class="pager-item-not-in-short-range">
            …
            <span class="bloko-form-spacer"></span><a class="bloko-button HH-Pager-Control" data-page="99" data-qa="pager-page" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=99">100</a><span class="bloko-form-spacer"></span></span><a class="bloko-button HH-Pager-Controls-Next HH-Pager-Control" data-qa="pager-next" data-page="1" rel="nofollow" href="/search/vacancy?L_is_autosearch=false&amp;area=1&amp;clusters=true&amp;enable_snippets=true&amp;text=Python&amp;page=1">дальше</a><span class="bloko-form-spacer"></span></div><!--/noindex--></div></div></div></div></div>

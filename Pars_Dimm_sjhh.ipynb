# %%
# Demonstrating selecting multiple lines for commenting
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import pandas as pd
import time

# %%
def hh_parce(base_url, headers, pages):
    # Чтобы сайт думал, что с этого браузера зашел один пользователь для просмотра вакансий
    jobs = []
    session = requests.Session()
    for i in range(pages):
        request = session.get(base_url, headers=headers)
        if request.status_code == 200:
            soup = bs(request.content, 'lxml')
            divs = soup.find_all('div', {'data-qa':'vacancy-serp__vacancy'})
            for div in divs:
                title = div.find('a', {'class': 'bloko-link HH-LinkModifier'}).text
                href = div.find('a', {'class': 'bloko-link HH-LinkModifier'})['href']
                company = div.find('a', {'data-qa':'vacancy-serp__vacancy-employer'}).text
                compensation = div.find('div', {'data-qa': 'vacancy-serp__vacancy-compensation'})
                if not compensation:
                    compensation1 = 'Нет данных'
                    compensation2 = 'Нет данных'
                else:
                    compensation = compensation.text.replace('.','')

                    if '-' in compensation:
                        compensation1 = compensation.split('-')[0]
                        compensation2 = compensation.split('-')[1]
                        #compensation2 = compensation2.replace('.','')
                        compensation1 += compensation2[-4   :]
                    elif 'от' in compensation:
                        compensation1 = compensation.replace('от ','')
                        compensation2 = 'Нет данных'
                    elif 'до' in compensation:
                        compensation1 = 'Нет данных'
                        compensation2 = compensation.replace('до ','')

                #print(compensation1, end='\t')
                #print(compensation2)
                jobs.append({
                    'title': title,
                    'href': href,
                    'company': company,
                    'compensation1': compensation1,
                    'compensation2': compensation2,
                    'source':'hh.ru'
                })
            base_url = 'https://hh.ru' + soup.find('a', {'class': 'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})['href']
            time.sleep(1)
        else:
            print('Ошибка')

    jobs = pd.DataFrame(jobs)
    return jobs

# %%
base_url = 'https://hh.ru' + soup.find('a', {'class': 'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})['href']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-cdba0bd9f4d2> in <module>
# ----> 1 base_url = 'https://hh.ru' + soup.find('a', {'class': 'bloko-button HH-Pager-Controls-Next HH-Pager-Control'})['href']
#
# NameError: name 'soup' is not defined

# %%
hh_parce(base_url, headers, 3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-aa7169360b8b> in <module>
# ----> 1 hh_parce(base_url, headers, 3)
#
# NameError: name 'base_url' is not defined

# %%
def sj_parce(base_url, headers, pages):
    # Чтобы сайт думал, что с этого браузера зашел один пользователь для просмотра вакансий
    jobs = []
    session = requests.Session()
    for i in range(pages):
        request = session.get(base_url, headers=headers)
        if request.status_code == 200:
            soup = bs(request.content, 'lxml')
            divs = soup.find_all('div', {'class':'_3zucV _2GPIV f-test-vacancy-item i6-sc _3VcZr'})
            for div in divs:
                title = div.find('div', {'class': '_3mfro CuJz5 PlM3e _2JVkc _3LJqf'}).text
                href = div.find('div', {'class': '_3mfro CuJz5 PlM3e _2JVkc _3LJqf'}).findParent()['href']
                # В одном месте нет названия фирмы
                company = div.find('span', {'class': '_3mfro _3Fsn4 f-test-text-vacancy-item-company-name _9fXTd _2JVkc _3e53o _15msI'})
                if not company:
                    company = 'Нет данных'
                else:
                    company = company.getText()
                #print(company)
                compensation = div.find('span', {'class': '_3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz'}).text
                if '—' in compensation:
                    compensation1 = compensation.split('—')[0]
                    compensation2 = compensation.split('—')[1]
                    compensation1 += compensation2[-2:]
                elif 'от' in compensation:
                    compensation1 = compensation[3:]
                    compensation2 = 'Нет данных'
                elif 'договорённости' in compensation:
                    compensation1 = compensation
                    compensation2 = compensation
                elif 'до' in compensation:
                    compensation1 = 'Нет данных'
                    compensation2 = compensation[3:]

                #print(compensation1, end='\t')
                #print(compensation2)
                #print(compensation)
                jobs.append({
                    'title': title,
                    'href': 'https://www.superjob.ru'+href,
                    'company': company,
                    'compensation1': compensation1,
                    'compensation2': compensation2,
                    'source': 'superjob.ru'
                })
            base_url = 'https://www.superjob.ru' + \
                       soup.find('a', {'class': 'icMQ_ _1_Cht _3ze9n f-test-button-dalshe f-test-link-dalshe'})['href']
            time.sleep(1)
        else:
            print('Ошибка')
    jobs = pd.DataFrame(jobs)
    return jobs

# %%
query_text = 'программист'
num_pages = 3
headers =  {'accept':'*/*',
            'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.120 Safari/537.36'}
base_url_hh = f'https://hh.ru/search/vacancy?area=1&search_period=3&text={query_text}'
base_url_sj = f'https://www.superjob.ru/vacancy/search/?keywords={query_text}&geo%5Bt%5D%5B0%5D=4'

jobs = hh_parce(base_url_hh, headers, num_pages)
jobs
# jobs.to_csv('hh.csv')
# jobs_sj = sj_parce(base_url_sj, headers, num_pages)
# jobs_sj.to_csv('sj.csv')
# jobs = jobs.append(jobs_sj, ignore_index=True)
# jobs.to_csv('hh+sj.csv')
# Out:
#                                                 title  \
# 0   Инженер-программист ( front-end developer ) ju...
# 1                                     Программист 1 С
# 2                      Веб разработчик/программист с#
# 3      .NET C# Разработчик / .NET C# Developer Norway
# 4                             Разработчик/программист
# 5                               Front-end разработчик
# 6                                      Программист 1С
# 7                      Front-end разработчик (стажер)
# 8                              Программист в Германию
# 9                                     Программист SQL
# 10                                 Программист Delphi
# 11                                 PL/SQL разработчик
# 12                    Backend разработчик (Go/Golang)
# 13                                     Программист 1C
# 14                    Программист встраиваемых систем
# 15                    Разработчик ETL / автоматизатор
# 16  Инженер-разработчик (программист микроконтролл...
# 17  Web-программист / Web-разработчик / PHP-програ...
# 18  Fullstack web разработчик / Fullstack web deve...
# 19                                        Программист
# 20                                    PHP программист
# 21                                     Программист 1C
# 22                    Senior Backend-разработчик (C#)
# 23                           Backend-разработчик (C#)
# 24       Инженер-программист микроконтроллеров и FPGA
# 25    Ведущий/Старший программист (.Net C# Developer)
# 26                                     Программист 1С
# 27                Программист встраиваемых систем C++
# 28         Web-программист (PHP-программист, Backend)
# 29             Front-end программист, Web-программист
# 30                            PHP-программист Laravel
#
#                                                  href  \
# 0   https://hh.ru/vacancy/32697772?query=%D0%BF%D1...
# 1   https://hh.ru/vacancy/33814598?query=%D0%BF%D1...
# 2   https://hh.ru/vacancy/33961520?query=%D0%BF%D1...
# 3   https://hh.ru/vacancy/33940776?query=%D0%BF%D1...
# 4   https://hh.ru/vacancy/33409508?query=%D0%BF%D1...
# 5   https://hh.ru/vacancy/33922908?query=%D0%BF%D1...
# 6   https://hh.ru/vacancy/34028424?query=%D0%BF%D1...
# 7   https://hh.ru/vacancy/33703953?query=%D0%BF%D1...
# 8   https://hh.ru/vacancy/33812932?query=%D0%BF%D1...
# 9   https://hh.ru/vacancy/33932334?query=%D0%BF%D1...
# 10  https://hh.ru/vacancy/33758629?query=%D0%BF%D1...
# 11  https://hh.ru/vacancy/33767470?query=%D0%BF%D1...
# 12  https://hh.ru/vacancy/33223757?query=%D0%BF%D1...
# 13  https://hh.ru/vacancy/33949642?query=%D0%BF%D1...
# 14  https://hh.ru/vacancy/33849970?query=%D0%BF%D1...
# 15  https://hh.ru/vacancy/34212978?query=%D0%BF%D1...
# 16  https://hh.ru/vacancy/33924627?query=%D0%BF%D1...
# 17  https://hh.ru/vacancy/33952217?query=%D0%BF%D1...
# 18  https://hh.ru/vacancy/34224758?query=%D0%BF%D1...
# 19  https://hh.ru/vacancy/33949489?query=%D0%BF%D1...
# 20  https://hh.ru/vacancy/33948620?query=%D0%BF%D1...
# 21  https://hh.ru/vacancy/33958561?query=%D0%BF%D1...
# 22  https://hh.ru/vacancy/33362983?query=%D0%BF%D1...
# 23  https://hh.ru/vacancy/33362957?query=%D0%BF%D1...
# 24  https://hh.ru/vacancy/34126186?query=%D0%BF%D1...
# 25  https://hh.ru/vacancy/33952798?query=%D0%BF%D1...
# 26  https://hh.ru/vacancy/33950657?query=%D0%BF%D1...
# 27  https://hh.ru/vacancy/33747935?query=%D0%BF%D1...
# 28  https://hh.ru/vacancy/33960577?query=%D0%BF%D1...
# 29  https://hh.ru/vacancy/33760811?query=%D0%BF%D1...
# 30  https://hh.ru/vacancy/34027279?query=%D0%BF%D1...
#
#                                               company compensation1  \
# 0    Институт прикладных экономических исследовани...   100 000 руб
# 1                          Энергосистемы и Технологии   120 000 руб
# 2                                                 HTS   100 000 руб
# 3                                        ООО PaleBlue   200 000 руб
# 4                                   Главгосэкспертиза   100 000 руб
# 5                                           Just Food   120 000 руб
# 6                           Finex International, Inc.   120 000 руб
# 7                                         ООО Мед-Аск    10 000 руб
# 8                    ИП Сметанин Владимир Анатольевич     2 800 EUR
# 9                                              Гарант    90 000 руб
# 10                                        АО ИТЕРАЦИЯ    50 000 руб
# 11                                       АО ФлексСофт   100 000 руб
# 12                                      MillionAgents   150 000 руб
# 13                          ООО Территория технологий   100 000 руб
# 14                                    ООО АНТ-Эксперт   170 000 руб
# 15                                             HFLabs   150 000 руб
# 16                                  ООО Парус электро   100 000 руб
# 17                                    ООО РусВент МСК    50 000 руб
# 18                                  ООО ДОРОЖНАЯ СЕТЬ   150 000 руб
# 19                                      ООО Аврора-ИТ    60 000 руб
# 20                                ООО РАДУГА-ИНТЕРНЕТ    Нет данных
# 21                                     СОЛИНГ КОМПАНИ    70 000 руб
# 22                                           НИЦ Soft   180 000 руб
# 23                                           НИЦ Soft   120 000 руб
# 24                       ООО Климатические Технологии    80 000 руб
# 25                    Федеральная нотариальная палата   150 000 руб
# 26                                    ООО Оптзапчасть    Нет данных
# 27                                   ООО ЭИР ЛАБС РУС   150 000 руб
# 28                                             Гудвин    Нет данных
# 29                                       ООО ПРАЙСИВА    80 000 руб
# 30                                        ООО Вилмари    90 000 руб
#
#    compensation2 source
# 0    140 000 руб  hh.ru
# 1    140 000 руб  hh.ru
# 2     Нет данных  hh.ru
# 3    300 000 руб  hh.ru
# 4     Нет данных  hh.ru
# 5    180 000 руб  hh.ru
# 6    180 000 руб  hh.ru
# 7     10 000 руб  hh.ru
# 8      3 800 EUR  hh.ru
# 9    120 000 руб  hh.ru
# 10    75 000 руб  hh.ru
# 11   150 000 руб  hh.ru
# 12   200 000 руб  hh.ru
# 13   100 000 руб  hh.ru
# 14    Нет данных  hh.ru
# 15   195 000 руб  hh.ru
# 16    Нет данных  hh.ru
# 17    70 000 руб  hh.ru
# 18   180 000 руб  hh.ru
# 19    Нет данных  hh.ru
# 20   150 000 руб  hh.ru
# 21    70 000 руб  hh.ru
# 22   220 000 руб  hh.ru
# 23   180 000 руб  hh.ru
# 24    Нет данных  hh.ru
# 25   220 000 руб  hh.ru
# 26   130 000 руб  hh.ru
# 27   230 000 руб  hh.ru
# 28   250 000 руб  hh.ru
# 29   100 000 руб  hh.ru
# 30   110 000 руб  hh.ru
